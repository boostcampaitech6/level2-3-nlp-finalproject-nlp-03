# %%
import os
from langchain_community.vectorstores import Chroma
from langchain_core.documents import Document
from langchain_openai import OpenAIEmbeddings
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from dotenv import load_dotenv
from glob import glob
import pandas as pd

from langchain_community.document_loaders import PyPDFLoader
from langchain_community.document_loaders import Docx2txtLoader
from langchain_community.document_loaders import UnstructuredPowerPointLoader
from langchain_community.document_loaders import CSVLoader

from typing import Any, Dict, Iterator, List, Optional, Sequence, Union

# %%
load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# langsmith monitoring environment setting
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_ENDPOINT"]="https://api.smith.langchain.com"
os.environ['LANGCHAIN_API_KEY'] = 'ls__e15765918790425c8ef8ccdde35deed9'
os.environ['LANGCHAIN_PROJECT'] = 'self-querying-chroma-test01'

# %% [markdown]
# embedding

# %%
embeddings = HuggingFaceEmbeddings(
                    model_name="intfloat/multilingual-e5-large",
                    model_kwargs={'device': 'cuda'}, # streamlit에서는 gpu 없음
                    encode_kwargs={'normalize_embeddings': True}
                )

# %% [markdown]
# ### 데이터 불러오기

# %% [markdown]
# 참고 :
# - langchain_community/document_loaders/CSVLoader : https://github.com/langchain-ai/langchain/blob/master/libs/community/langchain_community/document_loaders/csv_loader.py
# - langchain_core/document_loaders/base.py : https://github.com/langchain-ai/langchain/blob/master/libs/core/langchain_core/document_loaders/base.py

# %%
import csv
import pandas as pd


def get_text(
        files_path : str, 
        column_list : Sequence[str] = (), 
        source_dict : Sequence[str] = {},
        metadata_columns : Sequence[str] = (),
    ):
    # column_list가 있으면 column list 열만 page_content에 넣음. 없으면 모든 열을 page_content에 넣음.

    file_list = glob(files_path + '/*')
    doc_list = []

    for file in file_list:
        if file.endswith('.csv'):
            with open(file, newline='') as csvfile:
                df = pd.read_csv(csvfile)
                documents = list(df_to_doc(df, files_path, column_list, source_dict, metadata_columns))
        elif file.endswith('.pdf'):
            pass
        doc_list.extend(documents)
        
    return doc_list
    
    
def df_to_doc(
        df : pd.DataFrame, 
        file_path : str, 
        column_list : Sequence[str] = (),
        source_dict : Dict = {},
        metadata_columns : Sequence[str] = (),
    ) -> Iterator[Document]:

    if not column_list: 
        column_list = df.columns.to_list()
        print(column_list)

    # if True in df[column_list].isna().any().to_list():
        # raise ValueError("The Required Column has empty value. Cannot process") 
    
    df.fillna('', inplace=True)

    # Joining the columns with a 'ᴥ'
    
    # column명 없이
    df['content'] = df.apply(lambda row: 'ᴥ'.join(row[column_list]), axis=1)
    
    # column명 넣어서
    # df['content'] = df.apply(lambda row: 'ᴥ'.join([f"{col};{val}" for col, val in row[column_list].items()]), axis=1)
    
    
    for _, data in df.iterrows():
        metadata = dict()

        for key, value in source_dict.items():
            metadata[key] = value
            
        for col in metadata_columns:
            metadata[col] = data[col]

        metadata['source'] = file_path
            
        yield Document(page_content=data['content'], metadata=metadata)

# %% [markdown]
# #### chroma db용 데이터 생성 및 chroma db 저장, 불러오기

# %%
tmp = get_text('./files/terms', 
               column_list=['단어', '설명', '출처', '정책명'], 
               source_dict={'category': '정보제공'}, 
               metadata_columns=['단어', '정책명'])

process_df = pd.read_csv('./files/기관_2024-03-04 - 기관_2024-03-04.csv')
tmp2 = df_to_doc(process_df, 
                './files', 
                column_list = ['정책명', '신청 절차', '제출 서류', '심사 발표', '신청 사이트 주소', '참고 사이트 주소1', '참고 사이트 주소2'],
                source_dict={'category':'절차문의'},
                metadata_columns=['정책명']
                )
tmp2 = list(tmp2)
tmp3 = get_text('./files/whole',
                column_list=['정책명', '답변', 'source'],
                source_dict={'category': '정보제공'},
                metadata_columns=['정책명']
                )
tmp.extend(tmp2)
tmp.extend(tmp3)
tmp
# tmp = get_text('./files/terms', column_list=['단어', '설명'])
# tmp = get_text('./files/terms')
# Out:
# /tmp/ipykernel_1138328/344558436.py:43: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna('', inplace=True)
# /tmp/ipykernel_1138328/344558436.py:43: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna('', inplace=True)
# [Document(page_content='기준금리ᴥ한국은행의 최고 결정기구인 금융통화위원회에서 연 8회에 걸쳐 회의를 통해서 결정하는 금리.ᴥhttps://www.moef.go.kr/sisa/dictionary/detail?idx=730ᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '기준금리', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='세대주ᴥ주민등록상의 세대란 주거 및 생계를 같이 하는 집단이며, 세대주는 그 세대를 대표하는 자로서, 주민의 신고에 의하여 선정이 가능합니다.ᴥhttp://www.gangdong.go.kr:8080/web/dongrenew/bbsamsa3/faq_amsa3/27395ᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '세대주', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='주택도시보증공사ᴥ주택도시보증공사(HUG)는 주택 관련 보증업무 및 정책사업의 수행과 주택도시기금의 효율적 운용·관리를 통하여 국민 삶의 질 향상에 이바지하기 위한 목적으로 주택도시기금법에 근거하여 설립된 국토교통부 산하 공기업이다.ᴥhttps://namu.wiki/w/%EC%A3%BC%ED%83%9D%EB%8F%84%EC%8B%9C%EB%B3%B4%EC%A6%9D%EA%B3%B5%EC%82%ACᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '주택도시보증공사', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='전세금안심대출보증ᴥ전세보증금반환보증 정의:\n임차인에게 전세보증금반환(전세보증금반환보증)과 금융기관에 전세자금대출의 원리금 상환(전세자금대출특약보증)을 함께 책임지는 보증상품\n\n전세보증금반환보증 지원대상:\n○ 대상주택 : 단독 · 다가구, 연립 · 다세대, 아파트, 주거용 오피스텔 \n * 다중주택, 공관, 가정어린이집, 공동생활가정, 지역아동센터, 노인복지시설은 보증대상이 아님 \n\n○ 보증채권자 : 전세자금을 대출하는 금융기관\n\n○ 주채무자 : 전세계약을 체결한 임차인으로서 전세자금대출을 받은 차주 (만 19세 이상의 자연인)\n\n○ 보증금액\n - 전세보증금반환보증: (보증한도 이내에서)보증신청인이 신청한 금액 \n - 전세자금대출특약보증: 전세대출금 \n\n○ 보증한도 \n 주택별 보증한도(다음 중 적은 금액 적용) 전세보증금*의 80% 이내\n * 보증부 월세계약(전세보증금이 있는 월세계약)인 경우 보증기간 전체에 해당하는 월세 합계액을 차감 \n 전세보증금반환보증금액*의 80% 이내\n * 전세보증금반환보증금액 한도\n · 주택가격(100%) - 선순위채권*\n  *선순위채권 :전세보증금보다 우선변제권이 인정되는 담보채권. \n 다만. 단독(다가구)주택의 경우에는 보증신청인보다 우선하는 선순위 전세보증금의 합계를 포함\n\n전세보증금반환보증 절차/방법:\n○ 주택 사업자, 금융기관이 협의하여 집단 취급 승인 신청\n - 집단 취급 심사 및 승인\n - 보증채무약정 체결\n - 건별 보증신청\n - 신용조사, 보증심사 후 보증서 발급\n\n전세보증금반환보증 구비서류:\n○ 전세금 안심대출보증 신청서\n - 개인 정보제공동의서(임차인용)\n - 보증채무약정서(고객 정보 활용 동의서 포함)\n - 전세금 안심대출보증 확약서\n - 확정일 자부 전세 계약서 원본\n - 그 밖에 심사에 필요한 서류\n\n※ 자세한 사항은 콜센터 문의\n\n전세보증금반환보증 접수기관:\n주택도시보증공사 / 연락처 051-955-5717\nᴥhttps://www.gov.kr/portal/service/serviceInfo/B55351100022ᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '전세금안심대출보증', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='채권양도협약기관ᴥ기존 한국토지주택공사(LH)에서 서울주택도시공사(SH)까지 확대\n\n국토교통부(장관 강호인)는 무주택 서민의 주거비 부담을 완화하고자 임차보증금 채권양도* 방식 취급기관을 확대한다.\n\n* 임차보증금 반환채권 양도방식이란?\n- 임대차 계약이 체결되어 임차인이 임대인(예: SH공사)에게 임차보증금을 납부하면 임차인은 임대인에게 임차보증금을 반환해달라는 채권이 발생하고, 주택도시기금은 그 채권을 양도받아 담보로 취득하고 버팀목전세대출 취급\n\n그간 버팀목 전세대출 시 보증료 부담이 없는 채권양도 방식은 한국토지주택공사(LH공사) 임대주택 입주자만 이용할 수 있었지만, 오는 10월 14일부터는 서울주택도시공사(SH공사)의 국민임대와 행복주택 입주자도 채권양도 방식이 가능해져 주거비가 절감된다.\n\n이번 조치로 인해 4천만원(평균대출액) 대출시 연간 64,800원, 10년 이용 시 약 65만원의 주거비(보증료)가 줄어들게 되며,\n* 버팀목 전세대출 보증료 = 4천만원(평균대출금) × 90%(보증비율) × 0.18%(보증요율(1억원 이하)) = 64,800원\n\nSH공사의 채권양도 해당 세대(국민·행복주택 2.2만세대)를 고려할 경우,10년간 총 145억원의 보증료가 절감될 전망이다.\n* 22,405세대 × 4천만원 × 90%(보증비율) × 0.18%(보증요율) × 10년=145억원\n\n아울러, SH공사의 임대주택 거주자가 버팀목 전세대출 신청 시 기금 수탁은행에 방문하면 채권양도까지 한 번에 신청할 수 있어 절차상 번거로움도 없다.\n\n국토부 관계자는 “대출채권 양도방식이 서민층의 주거비 경감에 도움이 되므로, 앞으로 추진 성과를 검토하여 채권양도를 원하는 타 공사와 다른 임대주택*에도 이를 확대할 예정”이라고 밝혔다.\n* 현재 SH공사의 임대주택 중 버팀목전세대출이 가능한 세대는 약 12만 2천세대\n\n2016.10.13 국토교통부ᴥhttps://www.bokjiro.go.kr/ssis-tbu/cms/pc/news/news/6516307.htmlᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '채권양도협약기관', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='청년전용 버팀목전세자금의 총소득 확인 서류ᴥ청년전용 버팀목전세자금 총소득 확인 서류: 소득구분별 아래의 서류\n(근로소득) 세무서(홈텍스)발급 소득금액증명원 또는 ISA 가입용 소득확인증명서, 연말정산용 원천징수영수증(원천징수부 등 포함), 급여내역이 포함된 증명서 (재직회사가 확인날인한 급여명세표, 임금대장, 갑근세 원천징수 확인서, 일용근로소득지급명세서) 중 택1\n(사업소득) 세무서(홈텍스)발급 소득금액증명원 또는 ISA 가입용 소득확인증명서, 사업소득 원천징수영수증(연말정산용), 세무사가 확인한 전년도 과세표준확정신고 및 납부 계산서 중 택1\n(연금소득) 연금수급권자확인서 등 기타 연금수령을 확인할 수 있는 지급기관 증명서 (연금수령액이 표기되지 않은 경우 연금수령 통장)\n(기타소득) 세무서(홈텍스)발급 소득금액증명원\n(무소득) 신고사실없음 사실증명원ᴥhttps://nhuf.molit.go.kr/FP/FP05/FP0502/FP05020302.jspᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '청년전용 버팀목전세자금의 총소득 확인 서류', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='청년전용 버팀목전세자금의 자산가액ᴥ자산가액은 대출신청인 및 배우자의 합산 부동산, 일반, 자동차 및 금융자산의 합계에서 금융부채 및 일반부채를 차감한 순자산가액으로 산정\n\n자산심사 세부 항목 및 산정기준(https://nhuf.molit.go.kr/FP/FP08/FP0813/FP081301.jsp?id=20&mode=S&currentPage=1&articleId=1160)\n\n※ 자산산정 기준시점 \n① 비금융자산(부동산, 일반자산, 자동차), 금융부채(공공기관·공제회 등 대출금) 및 일반부채(상가 및 오피스텔 임대보증금 등)는 대출접수일 기준으로 산정 \n② 금융자산 및 금융부채(금융기관 대출금, 신용카드연체금.미결제금)는 사회보장정보원이 금융기관 등에 요청하는 조회기준일*에 따르며,부정수급 방지를 위해 대출접수일 과거 3개월 시점 기준으로 금융자산을 조회 \n③ 다만, 대출접수일(조회기준일) 현재 명의인 또는 금액불일치 등으로 대출신청인이 이의신청한 경우 이의신청 자산에 대한 실질 조사를 통하여 자산가액은 변동 가능 \n* 조회기준일이란? 보건복지부 사회보장정보원이 금융기관 등의 장에게 금융정보 등을 조회 요청한 날로부터 3개월 전일에 속하는 달의 마지막 날 \n* 대출대상자의 개별적 상황에 따라 조회일 상이 가능(이 경우, 사회보장정보원기준에 따름)ᴥhttps://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&frameYn=&bizId=R2024010918589&dtlOpenYn=&plcyTpOpenTy=&plcyCmprInfo=&srchWord=&chargerOrgCdAll=&srchAge=&trgtJynEmp=&trgtJynEmp=&srchSortOrder=1&pageUnit=12ᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '청년전용 버팀목전세자금의 자산가액', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='가계금융복지조사ᴥ가계금융복지조사는 가계의 자산, 부채, 소득, 지출 등을 파악하여 국민의 생활수준과 가계의 재무건전성을 분석하고, 정부와 금융 당국이 국민의 삶을 지원하기 위한 복지와 금융정책을 추진하는데 활용되는 중요한 조사입니다.\n\n2023년 가계금융복지조사 결과:\n□ 가구의 경제상황\n\n ○ 2023년 3월말 기준 가구의 평균 자산은 5억 2,727만원, 부채는 9,186만원으로 순자산은 4억 3,540만원이며, \n     2022년 평균 소득은 6,762만원, 처분가능소득은 5,482만원으로 나타남\n\n  - 2023년 3월말 기준 가구의 평균 자산은 5억 2,727만원으로 전년대비 3.7% 감소\n  - 2023년 3월말 기준 가구의 평균 부채는 9,186만원으로 전년대비 0.2% 증가\n  - 2022년 가구의 평균 소득은 6,762만원으로 전년대비 4.5% 증가\n\n\n□ 소득분배지표\n\n ○ 2022년 균등화 처분가능소득 기준 지니계수는 전년대비 감소, 소득 5분위배율은 전년대비 감소, 상대적 빈곤율은 전년대비 증가\n\n  - 균등화 처분가능소득 기준 지니계수는 0.324으로 전년에 비해 0.005 감소\n  - 소득 5분위배율은 5.76배로 전년에 비해 0.07배p 감소\n  - 상대적 빈곤율은 14.9%로 전년에 비해 0.1%p 증가\nᴥhttps://kostat.go.kr/board.es?mid=a10502040100&bid=3215&act=view&list_no=306398&tag=&nPage=1&ref_bid=3213,3215,3214,11862,11863ᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '가계금융복지조사', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='소득 5분위ᴥ5분위 배율은 균등화 개인소득 순서에 따라 전체 인구를 5개 그룹으로 나누었을 때 소득이 높은 5분위에 해당하는 개인들의 평균소득과 소득이 낮은 1분위에 해당하는 개인들의 평균소득 사이의 비율로, 5분위 소득이 1분위 소득의 몇 배인지를 보여줍니다. 예를 들어 5분위 배율이 5.85이라면 5분위 소득이 1분위 소득보다 5.85배 많다는 것을 의미합니다.ᴥhttps://kostat.go.kr/menu.es?mid=b80304010200ᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '소득 5분위', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='대위변제ᴥ대위변제(代位辨濟, subrogation)란 민법에서, 채무자가 아닌 다른 사람(제3자 또는 공동채무자 등)이 채무자 대신 채무를 변제하고 구상권을 취득함으로써 채권자의 채권이 그 사람에게로 넘어가는 것을 말한다.ᴥhttps://ko.wikipedia.org/wiki/%EB%8C%80%EC%9C%84%EB%B3%80%EC%A0%9Cᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '대위변제', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='신용회복지원ᴥ개인신용회복지원제도란 개인 및 개인사업자 중 협약 등에서 구성하는 일정요건을 갖춘 채무자를 대상으로 신용불량에 따른 파산을 방지하고 그 경제적 회생기회를 도모하기 위하여 상환기간의 연장, 분할상환, 이자율 조정,변제기 유예, 채무감면 등의 채무조정 수단을 통해 신용회복을 지원하는 금융회사 공통의 업무를 말합니다.ᴥhttps://www.kdic.or.kr/rehabilitation/rehabilitation_03.doᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '신용회복지원', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='공공임대주택ᴥ공공주택이란 공공주택사업자가 국가 또는 지방자치단체의 재정이나 「주택도시기금법」에 따른 주택도시기금(이하 “주택도시기금”이라 함)을 지원받아 「공공주택 특별법」 또는 다른 법률에 따라 건설, 매입 또는 임차하여 공급하는 다음의 어느 하나에 해당하는 주택을 말합니다(「공공주택 특별법」 제2조제1호 및 「공공주택 특별법 시행령」 제2조).\n1. 임대 또는 임대한 후 분양전환을 할 목적으로 공급하는 규제「주택법」 제2조제1호에 따른 주택(이하 “공공임대주택”이라 함)으로서 다음의 공공임대주택을 말함: 영구임대주택, 국민임대주택, 행복주택, 통합공공임대주택, 장기전세주택, 분양전환공공임대주택, 기존주택등매입임대주택, 기존주택전세임대주택\n2. 분양을 목적으로 공급하는 주택으로서 규제「주택법」 제2조제5호에 따른 국민주택규모 이하의 주택(이하 “공공분양주택”이라 함)을 말함\n\nᴥhttps://easylaw.go.kr/CSP/common/CnpClsMain.laf?popMenu=ov&csmSeq=1769&ccfNo=1&cciNo=1&cnpClsNo=1ᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '공공임대주택', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='금융소비자보호법ᴥ이 법은 금융소비자의 권익 증진과 금융상품판매업 및 금융상품자문업의 건전한 시장질서 구축을 위하여 금융상품판매업자 및 금융상품자문업자의 영업에 관한 준수사항과 금융소비자 권익 보호를 위한 금융소비자정책 및 금융분쟁조정절차 등에 관한 사항을 규정함으로써 금융소비자 보호의 실효성을 높이고 국민경제 발전에 이바지함을 목적으로 한다.ᴥhttps://www.law.go.kr/%EB%B2%95%EB%A0%B9/%EA%B8%88%EC%9C%B5%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%EA%B4%80%ED%95%9C%EB%B2%95%EB%A5%A0ᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '금융소비자보호법', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='위법계약해지권ᴥ금융상품판매업자 또는 금융상품자문업자(이하 “금융상품판매업자등”이라 함)가 “① 적합성원칙”, “② 적정성원칙”, “③ 설명의무”, “④ 불공정영업행위 금지”, “⑤ 부당권유행위 금지” 규정을 위반하여 일반금융소비자와 금융상품에 관한 계약을 체결한 경우 해당 계약의 해지를 요구할 수 있는 것을 말합니다(「금융소비자 보호에 관한 법률」 제47조제1항 전단).ᴥhttps://easylaw.go.kr/CSP/CnpClsMain.laf?popMenu=ov&csmSeq=1771&ccfNo=1&cciNo=2&cnpClsNo=2ᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '위법계약해지권', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='수도권ᴥ “수도권”이란 서울특별시와 대통령령으로 정하는 그 주변 지역을 말한다. (수도권정비계획법 제2조 제1호)ᴥhttps://www.law.go.kr/%EB%B2%95%EB%A0%B9/%EC%88%98%EB%8F%84%EA%B6%8C%EC%A0%95%EB%B9%84%EA%B3%84%ED%9A%8D%EB%B2%95ᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '수도권', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='한국주택금융공사ᴥ한국주택금융공사(HF)는 주택금융 등의 장기적이고 안정적인 공급을 촉진해 국민의 복지증진과 국민경제의 발전에 이바지하기 위해 설립된 금융위원회 산하 기금관리형 준정부기관이다.ᴥhttps://namu.wiki/w/%ED%95%9C%EA%B5%AD%EC%A3%BC%ED%83%9D%EA%B8%88%EC%9C%B5%EA%B3%B5%EC%82%ACᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '한국주택금융공사', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='집단전세보증ᴥ공사의 사전승인을 받은 임대사업장 입주예정자의 임차중도금 및 잔금 대출을 위한 공사의 담보(보증서) 제공 시 소득 및 부채 수준에 따른 상환능력 평가를 생략할 수 있는 상품ᴥhttps://www.hf.go.kr/ko/sub02/sub02_01_03.doᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '집단전세보증', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='대환대출ᴥ금융기관에서 대출을 받아 이전의 대출금이나 연체금을 갚는 제도를 말한다. 특히 신용불량자 또는 신용카드 대금 연체자가 밀린 연체대금을 장기대출로 바꾸어 분할 납부하도록 하는 경우를 말한다. 이럴 경우 연체자는 신용불량자로 등록되는 것을 미리 막을 수 있는 도움을 주지만 금융기관으로부터 대환대출을 받기 위해서는 그동안의 대출 실적이나 신용도가 우수해야할 뿐만 아니라 대환대출의 이자가 보통 은행 대출 금리보다 높다는 점을 감수해야 한다. 반면 신용카드사들은 연체율 또는 부실채권을 줄일 수 있게 된다. A 금융기관에서 대출을 받아 B 금융기관의 부채를 갚는 대환대출 금융거래는 저금리대환대출, 아파트대환대출과 같은 변형된 대환대출도 만들어 냈다. 금리 변동에 따른 금융비용의 부담이나 아파트를 담보로 대출 받았지만 타 금융사의 담보대출 조건이 금리나 상환 조건 면에서 더 유리할 경우 대환대출을 받는 경우를 말한다.ᴥhttps://www.moef.go.kr/sisa/dictionary/detail?idx=906ᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '대환대출', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='전용면적ᴥ「주택법」(이하 “법”이라 한다) 제2조제6호 후단에 따른 주거전용면적(주거의 용도로만 쓰이는 면적을 말한다. 이하 같다)의 산정방법은 다음 각 호의 기준에 따른다.  <개정 2018. 4. 2.>\n\n1. 단독주택의 경우: 그 바닥면적(「건축법 시행령」 제119조제1항제3호에 따른 바닥면적을 말한다. 이하 같다)에서 지하실(거실로 사용되는 면적은 제외한다), 본 건축물과 분리된 창고ㆍ차고 및 화장실의 면적을 제외한 면적. 다만, 그 주택이 「건축법 시행령」 별표 1 제1호다목의 다가구주택에 해당하는 경우 그 바닥면적에서 본 건축물의 지상층에 있는 부분으로서 복도, 계단, 현관 등 2세대 이상이 공동으로 사용하는 부분의 면적도 제외한다.\n\n2. 공동주택의 경우: 외벽의 내부선을 기준으로 산정한 면적. 다만, 2세대 이상이 공동으로 사용하는 부분으로서 다음 각 목의 어느 하나에 해당하는 공용면적은 제외하며, 이 경우 바닥면적에서 주거전용면적을 제외하고 남는 외벽면적은 공용면적에 가산한다.\n\n가. 복도, 계단, 현관 등 공동주택의 지상층에 있는 공용면적\n\n나. 가목의 공용면적을 제외한 지하층, 관리사무소 등 그 밖의 공용면적ᴥhttps://www.law.go.kr/%EB%B2%95%EB%A0%B9/%EC%A3%BC%ED%83%9D%EB%B2%95%20%EC%8B%9C%ED%96%89%EA%B7%9C%EC%B9%99/%EC%A0%9C2%EC%A1%B0ᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '전용면적', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='다문화가구ᴥ다문화 가구는 가구원으로 외국인이나 귀화한 내국인을 포함하는 가구를 의미한다.ᴥhttps://data.si.re.kr/data/%ED%86%B5%EA%B3%84%EB%A1%9C-%EB%B3%B8-%EC%84%9C%EC%9A%B8-%EC%9D%B8%EA%B5%AC%ED%8E%B8/282ᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '다문화가구', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='가족관계증명서ᴥ가족관계증명서는 본인을 기준으로 부모, 배우자, 자녀를 표시하는 증명으로 보통 친자관계를 증명할 때 사용되며 형제자매는 표시가 안 되므로 형제자매 관계를 증명하기 위해서는 부모의 가족관계증명서를 발급받아야 합니다. 또한 이혼한 배우자의 정보도 표시되지 않기 때문에 본인의 혼인 사항을 확인하기 위해서는 혼인관계증명서를 발급받아야 합니다.\n\n■ 가족관계증명서 표시 내용\n\n- 본인의 등록기준지ㆍ성명ㆍ성별ㆍ본ㆍ출생연월일 및 주민등록번호\n- 부모의 성명ㆍ성별ㆍ본ㆍ출생연월일 및 주민등록번호(입양의 경우 양부모를 부모로 기록한다. 다만, 단독입양한 양부가 친생모와 혼인관계에 있는 때에는 양부와 친생모를, 단독입양한 양모가 친생부와 혼인관계에 있는 때에는 양모와 친생부를 각각 부모로 기록한다)\n- 배우자, 생존한 현재의 혼인 중의 자녀의 성명ㆍ성별ㆍ본ㆍ출생연월일 및 주민등록번호\n\n신청방법:        인터넷, 방문, 무인발급기\n수수료:        증명서 1통당 1,000원 / 인터넷으로 발급받을 때는 무료임 / 무인발급기 1통당 500원\n신청서:        가족관계등록부 등의 증명서 교부신청서(대법원 예규 제512호 별지 제11호 서식)\n구비서류: 신분증 지참\n처리기간:        즉시(근무시간 내 3시간)\n신청자격:        본인 또는 대리인\n인터넷 발급 사이트: https://efamily.scourt.go.kr/index.jspᴥhttps://allminwon.com/main/product_view.php?pro_num=A00901ᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '가족관계증명서', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='기본증명서ᴥ기본증명서는 개인의 기본 사항이 기재되어있는 서류(출생일, 출생장소, 사망, 개명, 친권, 정정 등)이다.\n\n■ 가족관계증명서 표시 내용\n공통 사항:        본인의 등록기준지, 성명, 성별, 본, 출생연월일, 주민등록번호특정증명서는 등록기준지, 본 포함여부를 선택할 수 있음\n개별 사항:        일반:        본인의 출생, 사망, 국적상실에 관한 사항\n상세:        본인의 출생, 사망, 인지, 친권, 국적, 개명, 성별 등에 관한 사항\n특정:        출생·사망·실종:        본인의 출생, 사망, 실종선고, 주민등록번호 · 출생연월일 정정 등에 관한 사항\n인지·친생자관계정정:        본인의 인지, 친생부인 등에 관한 사항\n친권·미성년후견:        전부) 본인의 친권, 후견, 미성년후견에 관한 모든 사항\n현재) 본인의 현재 유효한 친권, 후견, 미성년후견에 관한 사항\n개명·성본변경:        본인의 개명, 성·본창설, 성·본변경 등에 관한 사항\n국적 취득·상실:        본인의 귀화, 국적상실, 국적회복 등에 관한 사항\n성별정정:        본인의 성별정정, 주민등록번호 성별부분 정정 등에 관한 사항\n\n신청방법:        인터넷, 방문, 무인발급기\n수수료:        증명서 1통당 1,000원 / 인터넷으로 발급받을 때는 무료임 / 무인발급기 1통당 500원\n신청서:        가족관계등록부 등의 증명서 교부신청서(대법원 예규 제512호 별지 제11호 서식)\n구비서류: 신분증 지참\n처리기간:        즉시(근무시간 내 3시간)\n신청자격:        본인 또는 대리인\n인터넷 발급 사이트: https://efamily.scourt.go.kr/index.jspᴥhttps://efamily.scourt.go.kr/cs/CsBltnWrtGuideP.do?bltnbordId=0000007&guideCd=0000007002&guideYn=Yᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '기본증명서', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='주민등록등본ᴥ등본: 한 세대에 전입되어 있는 세대원 총원을 기록하는 문서이다. 기록되는 내용은 주로 세대총원, 세대원 주민등록번호, 전입일자, 세대주관계등이 기록된다.\n\n발급 사이트: https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000015&HighCtgCD=A01010001&Mcode=10200ᴥhttps://ko.wikipedia.org/wiki/%EC%A3%BC%EB%AF%BC%EB%93%B1%EB%A1%9Dᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '주민등록등본', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='한부모 가족 증명서ᴥ이 민원은 「한부모가족지원법」에 따른 한부모가족 보호대상자 증명에 관한 민원입니다.\n\n발급 사이트: https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=10601000001ᴥhttps://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=10601000001ᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '한부모 가족 증명서', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='소득금액증명원ᴥ이 민원은 종합소득 또는 연말정산 소득 또는 일용근로소득이 있는 자가 과세된 소득에 대한 소득금액을 증명받고자 신청하는 민원입니다.\n\n발급 사이트: https://www.gov.kr/main?a=AA020InfoCappViewApp&HighCtgCD=A09005&CappBizCD=12100000021ᴥhttps://www.gov.kr/main?a=AA020InfoCappViewApp&HighCtgCD=A09005&CappBizCD=12100000021ᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '소득금액증명원', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='사업자등록증ᴥ홈택스에 가입되어 있고 공인인증서가 있으면 세무서에 방문하지 않고 인터넷을 통하여 사업자등록 신청 및 구비서류 전자제출이 가능하며 사업자등록이 완료되면 사업자등록증 발급도 가능함\n(참조 : “홈택스 ( https://www.hometax.go.kr ) → 신청/제출 → 사업자등록신청/정정 등”)ᴥhttps://www.nts.go.kr/nts/cm/cntnts/cntntsView.do?mi=2444&cntntsId=7777ᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '사업자등록증', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='사업자등록증명원ᴥ이 민원은 사업자등록을 한 자가 사업내역을 증명 받고자 신청하는 민원입니다.\n\n발급 사이트: https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=12100000016ᴥhttps://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=12100000016ᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '사업자등록증명원', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='경력증명서ᴥ이 민원은 공공기관에서 근무하였던 자 또는 근무하고 있는 자가 경력사항을 증명 받을 때 혹은 퇴직할 때 신청하는 민원사무입니다.(현재 온라인 신청은 중앙부처(퇴직자) 및 지방자치단체 경력증명만 신청 가능합니다.)\ne-사람 독립망 운영기관(국방부, 방위사업청, 국세청, 경찰청, 대통령비서실, 대통령경호처)은 퇴직자 경력증명서를 온라인 신청할 수 없습니다. 해당 기관의 담당자에게 별도 요청바랍니다.\n\n발급 사이트: https://www.gov.kr/main?a=AA020InfoCappViewApp&CappBizCD=00000000008ᴥhttps://www.gov.kr/main?a=AA020InfoCappViewApp&CappBizCD=00000000008ᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '경력증명서', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='원천징수영수증ᴥ원천징수의무자는 사업소득에 대한 수입금액을 지급하는 때에 그 수입금액 등을 기재한 원천징수영수증을 사업소득자에게 발급\n사업소득에 대해 연말정산하는 경우 연말정산일이 속하는 달의 다음 달 말일까지 사업소득연말정산분에 대한 원천징수영수증을 발급ᴥhttps://www.nts.go.kr/nts/cm/cntnts/cntntsView.do?mi=6623&cntntsId=7903ᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '원천징수영수증', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='종합소득세 과세표준확정신고ᴥ소득세법 제70조(종합소득과세표준 확정신고) ④ 종합소득 과세표준확정신고를 할 때에는 그 신고서에 다음 각 호의 서류를 첨부하여 납세지 관할 세무서장에게 제출하여야 한다. 이 경우 제160조제3항에 따른 복식부기의무자가 제3호에 따른 서류를 제출하지 아니한 경우에는 종합소득 과세표준확정신고를 하지 아니한 것으로 본다.  <개정 2010. 12. 27., 2012. 1. 1., 2014. 1. 1.>\n\n3. 사업소득금액을 제160조 및 제161조에 따라 비치ㆍ기록된 장부와 증명서류에 의하여 계산한 경우에는 기업회계기준을 준용하여 작성한 재무상태표ㆍ손익계산서와 그 부속서류, 합계잔액시산표(合計殘額試算表) 및 대통령령으로 정하는 바에 따라 작성한 조정계산서. 다만, 제160조제2항에 따라 기장(記帳)을 한 사업자의 경우에는 기획재정부령으로 정하는 간편장부소득금액 계산서ᴥhttps://www.law.go.kr/LSW//lsLawLinkInfo.do?lsJoLnkSeq=1001061363&chrClsCd=010202&lsId=001565&print=printᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '종합소득세 과세표준확정신고', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='건강보험자격득실확인서ᴥ가입자의 건강보험 취득, 상실 이력을 제공\n\n발급 사이트: https://www.gov.kr/portal/service/serviceInfo/PTR000050333#noneᴥhttps://www.gov.kr/portal/service/serviceInfo/PTR000050333#noneᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '건강보험자격득실확인서', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content="등기사항증명서ᴥ등기사항을 증명하여 주는 민원문서.\n\n속칭 '등기부등본'. 과거에는 실제로 그것이 실제 서류 명칭이었으나, 등기부 자체가 완전히 전산화되면서 민원문서의 명칭도 그와 같이 바꾼 것이다. 2011년경에 바뀌었는데 아직도 등본이라고 부르는 사람들이 많다.\n\n발급 사이트: http://www.iros.go.kr/pos1/jsp/help2/jsp/001001004001.jspᴥhttps://namu.wiki/w/%EB%93%B1%EA%B8%B0%EC%82%AC%ED%95%AD%EC%A6%9D%EB%AA%85%EC%84%9Cᴥ청년전용 버팀목전세자금", metadata={'category': '정보제공', '단어': '등기사항증명서', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='건축물관리대장ᴥ이 민원은 건축물대장의 발급 또는 열람을 하기 위해서 신청하는 민원사무입니다( 다만, 평면도의 경우 건축물 소유자의 동의 등을 얻어야 발급이 가능하므로 직접 방문하여야 합니다.)\n\n발급 사이트: https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=15000000098ᴥhttps://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=15000000098ᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '건축물관리대장', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='기금e든든ᴥhttps://enhuf.molit.go.kr/index.jspᴥhttps://enhuf.molit.go.kr/index.jspᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '기금e든든', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='금융자산ᴥ"금융자산"이란 현금, 소유지분에 대한 증서 및 현금(또는 다른 금융자산)을 수취하거나 유리한 조건으로 금융자산을 교환할 수 있는 계약상의 권리를 말한다. (금융자산과 금융부채 회계처리지침)\n\n금융자산(Financial asset)은 예금, 채권, 기업 자본의 참여분 등 가치가 계약을 통해 파생되는, 무형자산이다. 금융자산은 보통 상품이나 부동산 등 유형자산보다 유동성이 더 크다.ᴥhttps://ko.wikipedia.org/wiki/%EA%B8%88%EC%9C%B5%EC%9E%90%EC%82%B0ᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '금융자산', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='금융부채ᴥ"금융부채"란 현금(또는 다른 금융자산)을 지급하거나 불리한 조건으로 금융자산을 교환해야 하는 계약상의 의무를 말한다. (금융자산과 금융부채 회계처리지침)\nᴥhttps://law.go.kr/LSW/admRulInfoP.do?admRulSeq=2100000117534ᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', '단어': '금융부채', '정책명': '청년전용 버팀목전세자금', 'source': './files/terms'}),
#  Document(page_content='취업지원ᴥ수급자의 취업활동에 도움이 되는 취업지원서비스를 제공하고 구직촉진수당을 지급하는 것ᴥhttps://www.kua.go.kr/uapaa010/selectKuaGudn.doᴥ국민취업지원제도', metadata={'category': '정보제공', '단어': '취업지원', '정책명': '국민취업지원제도', 'source': './files/terms'}),
#  Document(page_content='구직자취업촉진법ᴥ구직자 취업촉진 및 생활안정지원에 관한 법률ᴥhttps://www.kua.go.kr/uapaa010/selectKuaGudn.doᴥ국민취업지원제도', metadata={'category': '정보제공', '단어': '구직자취업촉진법', '정책명': '국민취업지원제도', 'source': './files/terms'}),
#  Document(page_content='취업지원서비스ᴥ수급자의 취업활동에 도움이 되도록 취업활동계획을 수립하고 취업지원 및 구직활동지원 프로그램을 제공하는 등, 구직 욕구와 취업 역량을 높이기 위해 지원하는 서비스ᴥhttps://www.kua.go.kr/uapaa010/selectKuaGudn.doᴥ국민취업지원제도', metadata={'category': '정보제공', '단어': '취업지원서비스', '정책명': '국민취업지원제도', 'source': './files/terms'}),
#  Document(page_content='구직촉진수당ᴥ수급자의 구직활동 및 생활 안정에 필요한 비용을 지원하기 위하여 제7조에 따른 수급자격을 인정받은 사람이 구직활동 의무를 이행하였을 때 지급하는 수당ᴥhttps://www.kua.go.kr/uapaa010/selectKuaGudn.doᴥ국민취업지원제도', metadata={'category': '정보제공', '단어': '구직촉진수당', '정책명': '국민취업지원제도', 'source': './files/terms'}),
#  Document(page_content='취업활동비용ᴥ구직촉진수당 수급요건에 해당하지 않는 수급자격자가 취업지원서비스에 참여하기 위해 필요한 비용(제16조에 따라 지원)ᴥhttps://www.kua.go.kr/uapaa010/selectKuaGudn.doᴥ국민취업지원제도', metadata={'category': '정보제공', '단어': '취업활동비용', '정책명': '국민취업지원제도', 'source': './files/terms'}),
#  Document(page_content='취업성공수당ᴥ수급자가 취업지원서비스기간 및 사후관리기간 중에 취업하여 취업 상태를 유지하는 경우 지급하는 수당(제17조)\nᴥhttps://www.kua.go.kr/uapaa010/selectKuaGudn.doᴥ국민취업지원제도', metadata={'category': '정보제공', '단어': '취업성공수당', '정책명': '국민취업지원제도', 'source': './files/terms'}),
#  Document(page_content='수급자격자ᴥ취업지원서비스 또는 구직촉진수당의 수급요건을 갖추어 수급자격을 인정받은 사람(제2조 제2호)ᴥhttps://www.kua.go.kr/uapaa010/selectKuaGudn.doᴥ국민취업지원제도', metadata={'category': '정보제공', '단어': '수급자격자', '정책명': '국민취업지원제도', 'source': './files/terms'}),
#  Document(page_content='수급자ᴥ수급자격자로서 취업지원서비스 또는 구직촉진수당을 받는 사람(제2조 제3호)\nᴥhttps://www.kua.go.kr/uapaa010/selectKuaGudn.doᴥ국민취업지원제도', metadata={'category': '정보제공', '단어': '수급자', '정책명': '국민취업지원제도', 'source': './files/terms'}),
#  Document(page_content='취업활동계획ᴥ수급자격자의 취업이라는 목표 달성을 위해 고용센터 담당자와 수급자격자가 협의하여 수립하는 구체적인 실천 계획, 취업지원 및 구직활동지원 프로그램 등에 관한 사항을 포함하여 수립함(제12조)ᴥhttps://www.kua.go.kr/uapaa010/selectKuaGudn.doᴥ국민취업지원제도', metadata={'category': '정보제공', '단어': '취업활동계획', '정책명': '국민취업지원제도', 'source': './files/terms'}),
#  Document(page_content='수급자격 신청일ᴥ제6조에 따른 취업지원서비스 수급요건을 갖춘 사람이 직업안정기관에 취업지원신청서(별지 제1호 서식)를 제출한 날(제8조)ᴥhttps://www.kua.go.kr/uapaa010/selectKuaGudn.doᴥ국민취업지원제도', metadata={'category': '정보제공', '단어': '수급자격 신청일', '정책명': '국민취업지원제도', 'source': './files/terms'}),
#  Document(page_content='지정일ᴥ구직촉진수당 수급자격을 인정받은 사람이 취업활동계획에서 정한 내용에 따라 취업지원 및 구직활동지원 프로그램을 이행하였음을 인정받기 위하여 지급주기 중에 구직촉진수당 지급신청서를 제출하는 지정된 날(제20조)ᴥhttps://www.kua.go.kr/uapaa010/selectKuaGudn.doᴥ국민취업지원제도', metadata={'category': '정보제공', '단어': '지정일', '정책명': '국민취업지원제도', 'source': './files/terms'}),
#  Document(page_content='구직활동ᴥ수급자가 구직촉진수당 또는 취업활동비용 수급을 위해, 수립된 취업활동계획에 따라 주어진 취업지원 및 구직활동지원 프로그램 등의 의무를 이행하는 일련의 활동ᴥhttps://www.kua.go.kr/uapaa010/selectKuaGudn.doᴥ국민취업지원제도', metadata={'category': '정보제공', '단어': '구직활동', '정책명': '국민취업지원제도', 'source': './files/terms'}),
#  Document(page_content='취업지원 프로그램ᴥ취업활동계획에 따라 수급자가 취업 의욕과 직업 적응 능력을 높이고 구직활동에 필요한 기술을 익힐 수 있도록 제공하는 프로그램으로서, ① 심리상담, 취업진로상담, ② 직업훈련, 창업지원, 해외취업지원, 일경험, ③ 복지 및 금융지원 연계 등이 있음(제13조)ᴥhttps://www.kua.go.kr/uapaa010/selectKuaGudn.doᴥ국민취업지원제도', metadata={'category': '정보제공', '단어': '취업지원 프로그램', '정책명': '국민취업지원제도', 'source': './files/terms'}),
#  Document(page_content='구직활동지원 프로그램ᴥ취업활동계획에 따라 제공하는 구직활동에 필요한 프로그램으로서, ① 일자리 소개 및 고용 정보 제공, ② 동행면접, ③ 이력서 작성 및 면접 기법 지원 등이 있음(제14조)ᴥhttps://www.kua.go.kr/uapaa010/selectKuaGudn.doᴥ국민취업지원제도', metadata={'category': '정보제공', '단어': '구직활동지원 프로그램', '정책명': '국민취업지원제도', 'source': './files/terms'}),
#  Document(page_content='취업지원서비스기간ᴥ수급자가 취업지원서비스를 받을 수 있는 기간으로, 제10조에 따라 수급자격자 인정 결정 알림을 받은 날부터 1년이 되는 날까지이며, 필요 시 6개월 범위 내에서 추가 연장이 가능함(제15조)ᴥhttps://www.kua.go.kr/uapaa010/selectKuaGudn.doᴥ국민취업지원제도', metadata={'category': '정보제공', '단어': '취업지원서비스기간', '정책명': '국민취업지원제도', 'source': './files/terms'}),
#  Document(page_content='사후관리기간ᴥ취업지원서비스기간(연장기간 포함)이 종료되었으나 취업하지 못한 사람에게 구인 정보를 제공하는 등의 관리를 하는 기간으로, 최대 4개월(3개월+1개월)까지 정할 수 있음(제15조 제4항)ᴥhttps://www.kua.go.kr/uapaa010/selectKuaGudn.doᴥ국민취업지원제도', metadata={'category': '정보제공', '단어': '사후관리기간', '정책명': '국민취업지원제도', 'source': './files/terms'}),
#  Document(page_content='주택청약종합저축ᴥ주택청약종합저축은 국민주택 및 민영주택을 공급받기 위해 가입하는 저축입니다.\n \n  주택청약종합저축은 누구든지 가입 가능하며, 모든 주택에 청약할 수 있습니다.\n  기존의 청약저축에 청약예부금 기능을 묶어 놓은 청약통장입니다.ᴥhttps://www.applyhome.co.kr/ar/ard/selectSubscriptVocabularyView.do#voca1ᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '주택청약종합저축', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='국민주택ᴥ주택청약과 관련하여 주택의 종류는 국민주택과 민영주택으로 나뉩니다.\n \n  국가, 지자체, LH 및 지방공사가 건설하는 주거전용면적 85m2 이하 (수도권, 도시지역이 아닌 읍·면은 100m2 이하)의 주택\n  국가나 지자체의 재정 또는 주택도시기금을 지원받아 건설·개량하는 주거전용 면적 85m2 이하의 주택\n  주택의 종류 및 청약통장에 대한 자세한 사항은 청약제도안내 > APT > 청약주택을 참고하시기 바랍니다.ᴥhttps://www.applyhome.co.kr/ar/ara/selectSubscrptIntroHouseView.doᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '국민주택', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='민영주택ᴥ주택청약과 관련하여 주택의 종류는 국민주택과 민영주택으로 나뉩니다.\n \n  국민주택을 제외한 주택을 민영주택이라 합니다.\n  주택의 종류 및 청약통장에 대한 자세한 사항은 청약제도안내 > APT > 청약주택을 참고하시기 바랍니다.ᴥhttps://www.applyhome.co.kr/ar/ara/selectSubscrptIntroHouseView.doᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '민영주택', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='공공주택ᴥ공공주택은 공공주택 사업자가 국가 또는 지방자치단체의 재정이나 주택도시기금을 지원받아 건설 또는 매입하여 공급하는 다음에 해당하는 주택을 말합니다.\n \n  공공임대주택 : 임대 또는 임대 후 분양전환을 목적으로 공급하는 주택\n  공공분양주택 : 분양을 목적으로 공급하는 주택으로서 국민주택규모*이하의 주택\n  * 국민주택규모 : 주거전용면적 85㎡ 이하, 수도권 및 도시지역 외 읍면은 100㎡ 이하\n  국토교통부 장관은 다음의 자 중에서 공공주택사업의 사업자를 지정 : 국가 또는 지자체, 한국토지주택공사 및 지방공사, 공공기관 중 대통령령으로 정하는 기관 등ᴥhttps://www.applyhome.co.kr/ar/ard/selectSubscriptVocabularyView.do#voca1ᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '공공주택', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='공공건설임대주택ᴥ공공건설임대주택은 공공주택 특별법에 따른 공공주택사업자가 직접 건설하여 공급하는 공공임대주택입니다.\n \n  공공주택은 공공임대주택과 공공분양주택으로 구분되고, 공공임대주택은 공공건설임대주택과 공공매입임대주택으로 구분됩니다. (공공주택 특별법 제2조)\n  85㎡ 초과 공공건설임대주택에 청약 시 2주택 이상을 소유한 자는 1순위 청약을 제한받습니다. (2순위로 청약)ᴥhttps://www.applyhome.co.kr/ar/ard/selectSubscriptVocabularyView.do#voca1ᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '공공건설임대주택', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='도시형 생활주택ᴥ도시형 생활주택은 300세대 미만의 국민주택규모*에 해당하는 주택으로서 도시지역에 건설하는 원룸형 주택, 단지형 연립주택 또는 단지형 다세대주택 등의 주택을 말합니다.\n \n * 국민주택규모 : 주거전용면적 85㎡ 이하, 수도권 및 도시지역 외 읍면은 100㎡ 이하\n \n  도시형 생활주택, 오피스텔, 생활숙박시설, (공공지원)민간임대주택은 아파트 청약신청과 달리 별도의 청약통장 없이 청약신청할 수 있으며 재당첨 제한 등의 당첨자(입주자) 관리제도가 없습니다.\n  자세한 사항은 청약제도안내 > 오피스텔/생활숙박시설/도시형/(공공지원)민간임대 청약안내 > 청약주택을 참고하시기 바랍니다.ᴥhttps://www.applyhome.co.kr/ar/arb/selectPROUSubscriptionHouseInfoView.doᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '도시형 생활주택', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='오피스텔ᴥ오피스텔은 업무를 주로 하며, 분양하거나 임대하는 구획 중 일부 구획에서 숙식을 할 수 있도록 한 건축물로서 국토교통부장관이 고시하는 기준에 적합하여야 합니다.\n \n  도시형 생활주택, 오피스텔, 생활숙박시설, 민간임대주택은 아파트 청약신청과 달리 별도의 청약통장 없이 청약신청할 수 있으며 재당첨 제한 등의 당첨자(입주자) 관리제도가 없습니다.\n  자세한 사항은 청약제도안내 > 오피스텔/생활숙박시설/도시형/(공공지원)민간임대 > 청약주택을 참고하시기 바랍니다.ᴥhttps://www.applyhome.co.kr/ar/arb/selectPROUSubscriptionHouseInfoView.doᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '오피스텔', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='공공지원 민간임대주택ᴥ공공지원 민간임대주택 임대사업자가 10년 이상 임대할 목적으로 취득하여 임대료 및 임차인의 자격 제한 등을 받아 임대하는 민간임대주택입니다.\n * 민간임대주택 : 임대 목적으로 제공하는 주택으로서 임대사업자가 민간임대주택에 관한 특별법(제5조)에 따라 등록한 주택. 민간건설임대주택과 민간매입임대주택으로 구분. (동법 제2조제1호)\n \n  도시형 생활주택, 오피스텔, 생활숙박시설, (공공지원)민간임대주택은 아파트 청약신청과 달리 별도의 청약통장 없이 청약신청할 수 있으며 재당첨 제한 등의 당첨자(입주자) 관리제도가 없습니다.\n  자세한 사항은 청약제도안내 > 오피스텔/생활숙박시설/도시형생활주택/(공공지원)민간임대 > 청약주택을 참고하시기 바랍니다.ᴥhttps://www.applyhome.co.kr/ar/arb/selectPROUSubscriptionHouseInfoView.doᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '공공지원 민간임대주택', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='청약통장(입주자저축)ᴥ1. 주택청약종합저축\n \n  - 국민주택과 민영주택을 공급받기 위해 가입하는 저축\n \n 2. 청약저축\n \n  - 국민주택을 공급받기 위해 가입하는 저축\n \n 3. 청약예금\n \n  - 민영주택을 공급받기 위해 가입하는 예금\n \n 4. 청약부금\n \n  - 주거전용면적 85㎡ 이하의 민영주택을 공급 받기 위해 가입하는 부금\n \n  청약저축, 청약예금, 청약부금은 2015년 9월 1일부터 신규가입이 중단되었습니다. (주택청약종합저축 가입 가능)\n  청약통장의 종류에 따라 청약 신청할 수 있는 주택의 종류가 달라집니다.\n  청약통장은 1인 1구좌에 한해 가입할 수 있습니다.\n  청약통장에 대한 자세한 사항은 청약제도안내 > APT > 청약통장을 참고하시기 바랍니다.ᴥhttps://www.applyhome.co.kr/ar/ara/selectSubscrptIntroBnkbView.doᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '청약통장(입주자저축)', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='청약저축ᴥ청약저축은 국민주택을 공급받기 위해 가입하는 저축입니다.\n 2015년 9월 1일부터 신규가입이 중단되었습니다. (주택청약종합저축 가입 가능)\n \n  청약저축에 대한 자세한 사항은 청약제도안내 > APT > 청약통장을 참고하시기 바랍니다.ᴥhttps://www.applyhome.co.kr/ar/ara/selectSubscrptIntroBnkbView.doᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '청약저축', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='청약예금ᴥ청약예금은 민영주택을 공급받기 위해 가입하는 저축입니다.\n 2015년 9월 1일부터 신규가입이 중단되었습니다. (주택청약종합저축 가입 가능)\n \n  청약예금에 대한 자세한 사항은 청약제도안내 > APT > 청약통장을 참고하시기 바랍니다.ᴥhttps://www.applyhome.co.kr/ar/ara/selectSubscrptIntroBnkbView.doᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '청약예금', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='청약부금ᴥ청약부금은 주거전용면적 85㎡ 이하의 민영주택을 공급받기 위해 가입하는 저축입니다.\n 2015년 9월 1일부터 신규가입이 중단되었습니다. (주택청약종합저축 가입 가능)\n \n  가입 후 일정요건을 충족하면 청약예금으로 변경할 수 있습니다. (가입 2년 경과하고 납입인정금액이 85㎡ 청약예금 예치금액 이상)\n  청약예금에 대한 자세한 사항은 청약제도안내 > APT > 청약통장을 참고하시기 바랍니다.ᴥhttps://www.applyhome.co.kr/ar/ara/selectSubscrptIntroBnkbView.doᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '청약부금', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='무주택세대구성원ᴥ무주택세대구성원이란 세대주)에 속한 자 전원이 주택을 소유하고 있지 않은 세대구성원을 말합니다.\n \n  주) 세대(세대에 속한 자)\n  세대는 다음 각 목의 사람(이하 “세대구성원”이라 함)으로 구성된 집단(주택공급신청자가 세대별 주민등록표등본에 등재되어 있지 않은 경우는 제외)입니다.\n \n  주택공급신청자\n  주택공급신청자의 배우자\n  주택공급신청자의 직계존속(배우자의 직계존속 포함) 및 직계비속\n  * 주택공급신청자 또는 주택공급신청자의 배우자와 세대별 주민등록표등본에 함께 등재된 경우에만 인정\n  주택공급신청자의 배우자의 직계비속\n  * 주택공급신청자와 세대별 주민등록표등본에 함께 등재되어 있는 경우에만 인정\n  예) 신청자와 동일한 주민등록표등본 상에 등재된 재혼한 배우자의 직계비속\n \n  ※ 형제, 자매, 동거인 등은 청약자와 동일한 주민등록표등본에 등재되어 있어도 청약자의 세대에 속한 자가 아닙니다.\n  ※ 배우자 분리세대인 경우 배우자 및 배우자와 동일한 세대를 이루고 있는 직계존속(배우자의 직계존속 포함) 및 직계비속을 포함\n  ※ 외국인은 주민등록법상 세대주나 세대원이 될 수 없으며, 주민등록 의무 대상이 아니기 때문에 무주택세대구성원이나 세대주 자격을 필요로 하는 주택에 청약신청이 불가능합니다. 만약, 청약신청 하여 당첨될 경우 부적격당첨자로 불이익을 받을 수 있습니다.\n \n  상기 무주택세대구성원 요건을 충족해야만 민영주택 특별공급 및 국민주택에 청약할 수 있습니다.\n \n  청약신청자 본인의 무주택기간은 만30세 (만30세 이전에 결혼한 경우 혼인신고일)부터 산정합니다.(다만, 다자녀특별공급 무주택기간은 청약신청자가 성년(만19세)이 되는 날부터 산정합니다.)\n  청약신청자의 배우자는 주민등록 분리세대인 경우에도 배우자 세대가 신청자와 동일한 주민등록표등본에 등재된 것으로 봅니다.\n  만60세 이상인 직계존속이 주택 또는 분양권등을 소유하고 있는 경우에는 신청자가 주택을 소유하지 않은 것으로 봅니다. 다만 공공임대주택 및 노부모부양 특별공급을 신청하려는 경우에는 주택을 소유한 것으로 봅니다. (주택공급에 관한 규칙 제53조)ᴥhttps://www.applyhome.co.kr/ar/ard/selectSubscriptVocabularyView.do#voca1ᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '무주택세대구성원', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='세대ᴥ주택청약 시 세대 기준\n \n 세대는 다음 각 목의 사람(이하 "세대구성원"이라 함)으로 구성된 집단(주택공급신청자가 세대별 주민등록표에 등재되어 있지 않은 경우는 제외)입니다.\n \n  가. 주택공급신청자\n  나. 주택공급신청자의 배우자\n  다. 주택공급신청자의 직계존속(배우자의 직계존속 포함) 및 직계비속(직계비속의 배우자 포함)\n  * 주택공급신청자 또는 주택공급신청자의 배우자와 세대별 주민등록표 상에 함께 등재되어 있는 경우에만 인정\n  라. 주택공급신청자의 배우자의 직계비속(직계비속의 배우자 포함)\n  * 주택공급신청자와 세대별 주민등록표상 함께 등재되어 있는 경우에만 인정\n  예) 신청자와 동일한 주민등록표 상에 등재된 재혼한 배우자의 직계비속 및 직계비속의 배우자\n \n ※ 형제,자매,동거인 등은 청약자와 동일한 주민등록표에 등재되어 있어도 청약자의 세대에 속한 자가 아닙니다.\n \n ※ 배우자 분리세대인 경우 배우자 및 배우자와 동일한 세대를 이루고 있는 직계존속(배우자의 직계존속 포함) 및 직계비속(직계비속의 배우자 포함)을 포함ᴥhttps://www.applyhome.co.kr/ar/ard/selectSubscriptVocabularyView.do#voca1ᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '세대', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='부양가족ᴥ다만, 직계존속과 그 배우자 중 한 명이라도 주택을 소유(분양권등 포함)하고 있는 경우에는 직계존속과 그 배우자 모두 부양가족으로 보지 않습니다.\n 이 경우, 「주택공급에 관한 규칙」 제53조제6호(60세 이상의 직계존속이 주택 또는 분양권등을 소유하고 있는 경우)에 해당되는 경우에도 부양가족으로 인정되지 않으나 제6호를 제외한 각 호에 해당하는 경우에는 주택 또는 분양권등을 소유하지 아니한 것으로 인정되어 부양가족으로 봅니다.\n \n  부양가족 가점 산정기준의 세부사항은 청약소통방 > 공지사항 > 주택청약 자격 체크리스트(Check List) 참조\n  주택소유여부 판정기준의 세부사항은 청약제도안내 > 주택청약 용어설명 > 주택소유여부 판정기준 참조\n  분양권등 : 주택소유로 보는 경우 등 세부사항은 청약제도안내 > 주택청약 용어설명 > 분양권등 참조\n \n  직계비속 : 자녀(부모가 모두 사망한 손자녀 포함)는 미혼으로 한정합니다.\n \n  * 주택공급신청자의 만30세 이상인 직계비속은 입주자모집공고일을 기준으로 최근 1년 이상 계속하여 주택공급신청자 또는 그 배우자와 같은 세대별 주민등록표에 등재된 경우에 부양가족으로 인정\n \n  * 재혼배우자의 자녀는 주택공급신청자와 같은 세대별 주민등록표에 등재된 경우에 부양가족으로 인정\n \n  * 혼인 중이거나 혼인한 적이 있는 자녀는 부양가족으로 보지 않음\n \n  국토교통부 주택기금과 ‘주택청약 자격 체크리스트(’19.12)’에 따라 외국인 직계비속은 부양가족으로 인정되지 않으며, 내국인 직계비속이라도 해외에 체류중*인 경우에는 부양가족에서 제외합니다.\n \n  * 만30세 미만 : 입주자모집공고일 기준 현재 계속하여 90일은 초과하여 해외에 체류중인 경우\n \n  * 만30세 이상 : 입주자모집공고일 기준 최근 1년 이내 계속하여 90일을 초과하여 해외에 체류한 경우\n  자세한 사항은 공고단지 청약연습> 청약가점계산기를 참고하시기 바랍니다.ᴥhttps://www.applyhome.co.kr/ap/apg/selectAddpntCalculatorView.doᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '부양가족', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='가점제ᴥ가점제는 3개의 가점항목에 대하여 산정한 점수(가점)가 높은 순으로 입주자를 선정하는 것을 말합니다.\n \n  가점항목 : 무주택기간(0~15년 이상), 부양가족수(0~6명 이상), 입주자 저축 가입기간(0~15년 이상)\n  민영주택의 입주자를 선정하는 방식은 가점제 및 추첨제가 있습니다.\n  민영주택의 주택규모별 가점제 비율은 APT청약안내 : 당첨자 선정 > 민영주택(가점제 ·추첨제)를 참고하시기 바랍니다.\n  자세한 사항은 공고단지 청약연습 > 청약가점계산기를 참고하시기 바랍니다.ᴥhttps://www.applyhome.co.kr/ar/ara/selectSubscrptIntroPreawnerSlctnView.do#cate2ᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '가점제', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='청약순위ᴥ당첨자(입주자)는 순위별로 선정합니다. 즉, 1순위 청약신청 접수 미달 시에만 2순위 청약신청 접수분 중 당첨자를 선정합니다.\n \n  동일한 청약순위 내에서의 당첨자 선정방식은 주택의 종류, 크기 및 주택건설지역에 따라 달라집니다.\n  자세한 사항은 청약제도안내 > APT > 당첨자 선정을 참고하시기 바랍니다.ᴥhttps://www.applyhome.co.kr/ar/ara/selectSubscrptIntroPreawnerSlctnView.doᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '청약순위', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='지역별 예치금액ᴥ민영주택 청약신청 시 지역별, 전용면적별 예치금액입니다.\n \n 청약부금 가입자는 85㎡ 이하 민영주택에만 청약신청할 수 있습니다.\n \n 지역/전용면적별 예치금액\n \n (단위 : 만원)\n 지역/전용면적별 예치금액이 나와있는 테이블입니다. 구분 서울/부산 기타 광역시 기타 시/군\n 85㎡ 이하 300 250 200\n 102㎡ 이하 600 400 300\n 135㎡ 이하 1,000 700 400\n 모든 면적 1,500 1,000 500\n \n (“지역”은 입주자모집공고일 현재 주택공급신청자의 주민등록표에 따른 거주지역 기준임)ᴥhttps://www.applyhome.co.kr/ar/ard/selectSubscriptVocabularyView.do#voca1ᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '지역별 예치금액', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='소형·저가주택 등 소유자를 무주택자로 보는 경우ᴥ* 민영, 국민주택의 모든 공급유형 청약 시 적용되며, 공공임대주택은 적용되지 않습니다.\n 소형·저가주택 등이란\n \n 입주자모집공고일 현재 전용면적 60제곱미터 이하로서 아래의 “소형·저가주택 등의 가격 산정”에 따른 주택가격이 1억원(수도권은 1억6천만원) 이하인 주택 또는 분양권등을 말합니다. 주택공급신청자가 속한 세대가 소형·저가주택 등을 1호 또는 1세대만 소유하고 있는 경우, 민영, 국민주택의 모든 공급유형 청약 시 주택을 소유하지 아니한 것으로 봅니다. 단, 공공임대주택 청약 시에는 적용되지 않습니다.\n 소형·저가주택 등의 가격 산정\n \n 다음의 구분에 따라 가격을 산정합니다. 다만, 2007년 9월 1일 전에 주택을 처분한 경우에는 2007년 9월 1일 전에 공시된 주택공시가격(「부동산 가격공시에 관한 법률」 제16조 또는 제17조에 따라 공시된 가격) 중 2007년 9월 1일에 가장 가까운 날에 공시된 주택공시가격에 따릅니다.\n \n  가. 입주자모집공고일 후에 주택을 처분하는 경우: 입주자모집공고일에 가장 가까운 날에 공시된 주택공시가격\n  나. 입주자모집공고일 이전에 주택이 처분된 경우: 처분일 이전에 공시된 주택공시가격 중 처분일에 가장 가까운 날에 공시된 주택공시가격\n  다. 분양권등의 경우: 공급계약서의 공급가격(선택품목에 대한 가격은 제외)ᴥhttps://www.applyhome.co.kr/ar/ard/selectSubscriptVocabularyView.do#voca1ᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '소형·저가주택 등 소유자를 무주택자로 보는 경우', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='주택 처분 시 무주택기간 기준일ᴥ무주택기간 또는 주택 소유는 다음 각 호 서류의 해당일을 기준으로 합니다. 다만, 제1호와 제2호의 처리일자가 다를 경우에는 먼저 처리된 날을 기준으로 합니다.\n \n  1. 건물 등기사항증명서 : 등기접수일\n  2. 건축물대장등본 : 처리일\n  3. 분양권등에 관한 계약서 : 「부동산 거래신고 등에 관한 법률」 제3조에 따라 신고된 공급계약체결일\n  4. 매매를 통해 취득하고 있는 분양권등의 매매계약서\n  가. 분양권등의 매매 후 「부동산 거래신고 등에 관한 법률」 제3조에 따라 신고된 경우에는 신고서상 매매대금 완납일\n  나. 분양권등을 증여나 그 밖의 사유로 처분한 경우에는 사업주체와의 계약서상 명의변경일\n  5. 그 밖에 주택소유여부를 증명할 수 있는 서류인 경우에는 시장 또는 군수 등 공공기관이 인정하는 날ᴥhttps://www.applyhome.co.kr/ar/ard/selectSubscriptVocabularyView.do#voca1ᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '주택 처분 시 무주택기간 기준일', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='자산보유기준ᴥ건축물 \n \n  건축물가액은 해당 세대가 소유하고 있는 모든 건축물의 지방세정 시가표준액으로 하되, 없는 경우 지자체장이 결정한 시가표준액 적용\n \n 건축물 종류에 따른 지방세전 시가표준액 건축물 종류 지방세정 시가표준액\n 주택 공동주택 (아파트, 연립, 다세대) 공동주택가격 (국토교통부)\n 단독주택 표준주택가격 (국토교통부) 또는 개별주택가격 (시·군·구청장)\n 주택 외 지방자치단체장이 결정한 가액\n \n  주택 : 부동산가격공시알리미 https://www.realtyprice.kr\n  주택외 : 위택스>지방세정보>시가표준액 조회 https://www.wetax.go.kr\n \n 토지 \n \n  토지가액은 지목에 상관없이 해당 세대가 소유하고 있는 모든 토지의 공시가격(표준지·개별공시지가)에 면적을 곱한 금액. 단, 아래 경우는 제외\n  「농지법」제2조제1호에 따른 농지로서 같은 법 제49조에 따라 관할 시ㆍ구ㆍ읍ㆍ면의 장이 관리하는 농지원부에 같은 농업인과 소유자로 등재된 경우\n  「초지법」제2조제1호에 따른 초지로서 소유자가「축산법」제22조에 따른 축산업 허가를 받은 사람이며 축산업 허가증의 사업장 소재지와 동일한 주소인 경우\n  공부상 도로, 구거, 하천 등 공공용지로 사용되고 있는 경우\n  종중소유 토지(건축물을 포함) 또는 문화재가 건립된 토지 등 해당 부동산의 사용, 처분 등이 금지되거나 현저히 제한을 받는 경우로서 입주(예정)자가 구체적인 사실관계를 입증하는 경우\n  건축물가액에 토지가액이 포함되지 않는 비주거용 건축물(상가, 오피스텔 등)의 부속토지도 토지가액에 포함(개별공시지가 기준)\n  토지 : 부동산가격공시알리미 https://www.realtyprice.krᴥhttps://www.applyhome.co.kr/ar/ard/selectSubscriptVocabularyView.do#voca1ᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '자산보유기준', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='과밀억제권역ᴥ과밀억제권역은 수도권의 인구와 산업을 적정하게 배치하기 위하여 구분한 지역으로서, 인구와 산업이 지나치게 집중되었거나 집중될 우려가 있어 이전하거나 정비할 필요가 있는 지역입니다.\n \n  과밀억제권역에 해당하는 지역의 목록은 수도권정비계획법 시행령 별표1에서 확인하실 수 있습니다.\n  과밀억제권역은 주택청약 시 재당첨 제한 기간을 별도로 정하고 있습니다ᴥhttps://www.applyhome.co.kr/ar/ard/selectSubscriptVocabularyView.do#voca1ᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '과밀억제권역', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='청약과열지역ᴥ주택법 제63조의2제1항제1호에 따라 지정된 조정대상지역 지역입니다. 이 지역은 주택가격, 청약경쟁률, 분양권 전매량 및 주택보급률 등을 고려하였을 때 주택 분양 등이 과열되어 있거나 과열될 우려가 있는 지역으로 재당첨 제한 또는 1순위 당첨 등이 제한됩니다. 청약하려는 주택이 청약과열지역의 주택인지 여부는 해당 주택의 입주자모집공고문에서 확인할 수 있습니다.\n \n  아래의 청약자는 청약과열지역에서 공급되는 주택에 1순위로 청약할 수 없습니다.\n  민영주택\n  세대주가 아닌 자\n  과거 5년 이내에 다른 주택에 당첨된 자의 세대에 속한 자\n  2주택(청약신청 하려는 주택이 토지임대부 분양주택인 경우에는 1주택) 이상을 소유한 세대에 속한 자\n  * 민영주택 청약 시에는 배우자의 직계존속도 세대에 속한 자에 포함됨\n  국민주택\n  세대주가 아닌 자\n  과거 5년 이내에 다른 주택에 당첨된 자가 속해 있는 무주택세대구성원\n \n  청약과열지역에서 공급되는 주택(민영주택 및 분양가상한제 미적용 주택 포함)은 당첨시 재당첨 제한이 적용됩니다.\n \n 청약과열지역\n \n * 관련법률 : 주택공급에 관한 규칙 제19조제4항2호ᴥhttps://www.applyhome.co.kr/ai/aic/selectSpecltSubscrptRndAreaList.do#specul_2ᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '청약과열지역', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='조정대상지역(과열지역)ᴥ조정대상지역(과열지역)은 주택가격, 청약경쟁률, 분양권 전매량 및 주택보급률 등을 고려하였을 때 주택 분양 등이 과열되어 있거나 과열될 우려가 있는 지역으로 국토교통부장관이 지정\n \n  오피스텔(생활숙박시설) 거주자 우선 분양\n  투기과열지구 또는 조정대상지역(과열지역)에서 공급되는 오피스텔(생활숙박시설)은 분양분의 20% 범위에서 그 건축물 건설지역의 거주자에게 우선 분양하여야 함.ᴥᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '조정대상지역(과열지역)', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='투기과열지구ᴥ투기과열지구는 주택가격의 안정을 위하여 필요한 경우에 국토교통부 장관 또는 시·도지사가 지정하는 지역입니다. 청약하려는 주택이 투기과열지구내 주택인지 여부는 해당 주택의 입주자모집공고문에서 확인할 수 있습니다.\n \n  아래의 해당하는 청약자는 투기과열지구내 주택에 1순위로 청약할 수 없습니다.\n  가. 민영주택\n  세대주가 아닌 자\n  과거 5년 이내에 다른 주택에 당첨된 자의 세대에 속한 자\n  2주택(청약신청 하려는 주택이 토지임대부 분양주택인 경우에는 1주택) 이상을 소유한 세대에 속한 자\n  * 민영주택 청약 시에는 배우자의 직계존속도 세대에 속한 자에 포함됨\n  나. 국민주택\n  세대주가 아닌 자\n  과거 5년 이내에 다른 주택에 당첨된 자가 속해 있는 무주택세대구성원\n  투기과열지구내 주택(민영주택 및 분양가상한제 미적용주택 포함)은 당첨시 재당첨 제한이 적용됩니다.\n \n 투기과열지구\n \n * 관련법률 : 주택법 제63조 (투기과열지구 지정 현황은 국토교통부 홈페이지 > 정책자료 > 법령정보 > 행정규칙(훈령, 예규, 고시)에서 확인하실 수 있습니다.)ᴥhttps://www.applyhome.co.kr/ai/aic/selectSpecltSubscrptRndAreaList.do#specul_1ᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '투기과열지구', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='대규모 택지개발지구 등ᴥ「택지개발촉진법」에 따른 택지개발이 시행되는 지역(수도권지역에 한정), 「공공주택 특별법」에 따른 공공주택지구조성사업이 시행되는 지역(수도권지역에 한정) 및 「경제자유구역의 지정 및 운영에 관한 법률」에 따른 경제자유구역 개발사업이 시행되는 구역으로서 면적이 66만㎡ 이상인 지역\n \n  대규모 택지개발지구에서의 입주자(당첨자) 선정방식 : 해당 시·도 거주자에게 일반공급 물량의 50%(경기도는 해당건설지역에 30%, 그 외 경기도에 20%)를 우선 공급한 뒤, 나머지 50%를 기타지역 거주자에게 공급합니다.\n  자세한 사항은 청약제도안내 > APT청약안내 > 당첨자선정을 참고하시기 바랍니다.ᴥhttps://www.applyhome.co.kr/ar/ara/selectSubscrptIntroPreawnerSlctnView.doᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '대규모 택지개발지구 등', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='대규모 택지개발지구 등 우선공급ᴥ수도권내 대규모 택지개발지구에서의 지역별 입주자(당첨자) 선정방식\n \n  주택건설지역이 특별시 또는 광역시(인천)인 경우 해당 시·도 거주자에게 일반공급 물량의 50% 를 우선 공급한 뒤, 나머지 50%를 기타지역 거주자에게 공급합니다.\n  주택건설지역이 경기도인 경우해당 주택건설지역에 30%, 그 외 경기도에 20%를 우선 공급한 뒤, 나머지 50%를 기타지역 거주자에게 공급합니다.\n \n <예시1> 서울 또는 인천지역 대규모 택지개발지구인 100세대 공급의 경우 공급세대수 순위 접수건수 순위내 경쟁률\n (미달세대수) 공급세대 및 경쟁률 산출식\n (소수점 이하 반올림)\n 100세대 1순위 해당지역 55 1.10 \n \n 공급세대 : 100세대 × 50% = 50세대\n \n 경쟁률 : 55명 ÷ 50세대 = 1.1\n 기타지역 15 (Δ30) \n \n 공급세대 : 100세대 × 50% = 50세대\n \n 미달세대 : 50세대 - 20명1) = 30세대2)\n 2순위 해당지역 30 2.00 \n \n 공급세대 : 미달주택30세대 × 50% = 15세대\n \n 경쟁률 : 30명 ÷ 15세대 = 2.0\n 기타지역 30 3.00 \n \n 공급세대 : 미달주택30세대 × 50% = 15세대\n \n 경쟁률 : 45명3) ÷ 15세대 = 3.0\n \n  1) 1순위 해당지역 청약신청자 중 입주자로 선정되지 못한 5명(55명 - 50명) + 1순위 기타지역 청약신청자 15명 = 20명\n  2) 미달된 세대는 순위 내 다음지역 공급량으로 전환\n  3) 2순위 해당지역 청약신청자 중 입주자로 선정되지 못한 15명(30명-15명) + 2순위 기타지역 청약신청자 30명 = 45명\n  * 2순위 기타지역에서 선정되지 않은 청약신청자(30명) 중 예비입주자 선정\n \n <예시2> 성남(특별시, 광역시 이외 경기지역) 대규모 택지개발지구인 경우 공급세대수 순위 접수건수 순위내 경쟁률\n (미달세대수) 공급세대 및 경쟁률 산출식\n (소수점 이하 반올림)\n 100세대 1순위 해당지역 25 (Δ5) \n \n 공급세대 : 100세대 × 30% = 30세대\n \n 미달세대 : 30세대 - 25명 = 5세대1)\n 기타경기 50 2.00 \n \n 공급세대 : 100세대 × 20% + 5 = 25세대\n \n 경쟁률 : 50명 ÷ 25세대 = 2.00\n 기타지역 5 (Δ20) \n \n 공급세대 : 100세대 × 50% = 50세대\n \n 미달세대 : 50명 - 30명2) = 20세대1)\n 2순위 해당지역 9 1.50 \n \n 공급세대 : 20세대 × 30% = 6세대\n \n 경쟁률 : 9명 ÷ 6세대 = 1.50\n 기타경기 3 1.50 \n \n 공급세대 : 20세대 × 20% = 4세대\n \n 경쟁률 : 6명3) ÷ 4세대 = 1.50\n 기타지역 18 20 \n \n 공급세대 : 20세대 × 50% = 10세대\n \n 경쟁률 : 20명4) ÷ 10세대 = 2.00\n \n  1) 미달된 세대는 다음순위(또는 순위 내 다음지역)공급물량으로 전환\n  2) 1순위 기타경기 청약신청자 중 입주자로 선정되지 못한 25명(50명-25명)+1순위 기타지역 청약신청자5명=30명\n  3) 2순위 해당지역 청약신청자 중 입주자로 선정되지 못한 3명(9명-6명)+2순위 기타경기 청약신청자 3명=6명\n  4) 2순위 기타경기 청약신청자 중 입주자로 선정되지 못한 2명(6명-4명)+2순위 기타경기 청약신청자 18명=20명\n \n  - 소수점 이하는 반올림으로 처리하되, 공급세대가 적은(1~3세대) 경우 지역우선공급의 취지를 감안하여 선순위 지역에 공급 물량 우선 배분\n \n <예시3> 공급세대가 적은(1~3세대) 경우 지역별 배분 방식 공급가구 공급지역이 서울인 경우\n (해당 50%, 기타 50%) 공급지역이 성남인 경우\n (해당 30%, 경기 20%, 기타 50%)\n 1 서울 1, 기타지역 0 성남 1, 기타 경기 0, 기타지역 0\n 2 서울 1, 기타지역 1 성남 1, 기타 경기 1, 기타지역 0\n 3 서울 2, 기타지역 1 성남 1, 기타 경기 1, 기타지역 1ᴥhttps://www.applyhome.co.kr/ar/ard/selectSubscriptVocabularyView.do#voca1ᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '대규모 택지개발지구 등 우선공급', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='(해당)주택건설지역ᴥ주택을 건설하는 특별시, 광역시, 특별자치시, 특별자치도 또는 시·군의 행정구역을 말합니다. 다만, 주택건설용지를 공급하기 위한 택지개발사업지구 등이 둘 이상의 특별시, 광역시, 특별자치시 또는 시·군의 행정구역에 걸치는 경우에는 해당 행정구역 모두를 같은 주택건설지역으로 봅니다.\n \n  청약신청 시 해당 주택건설지역에 거주하는 자 외에 인근 주택건설지역에 거주하는 자도 청약신청할 수 있습니다.\n  자세한 사항은 청약제도안내 > APT청약안내 > 당첨자선정을 참고하시기 바랍니다.ᴥhttps://www.applyhome.co.kr/ar/ara/selectSubscrptIntroPreawnerSlctnView.doᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '(해당)주택건설지역', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='해당 주택건설지역 거주자 우선공급ᴥ동일 순위 내에서 해당 주택건설지역에 거주하는 청약신청자에게 우선적으로 공급되고 미달 시 잔여세대가 인근(기타)지역에 거주하는 청약신청자에게 공급됩니다. 다만, 수도권 내 대규모 택지개발지구 및 행정중심복합도시 예정지역(세종특별자치시)등은 별도의 기준을 적용합니다.\n \n  해당 주택건설지역: 주택을 건설하는 특별시, 광역시, 특별자치시, 특별자치도 또는 시·군의 행정구역과 도시지역\n  예) 서울특별시, 인천광역시, 경남 진주시 등\n  인근(기타)지역의 범위\n  ① 서울특별시, 인천광역시 및 경기도 지역\n  ② 대전광역시, 세종특별자치시 및 충청남도\n  ③ 충청북도\n  ④ 광주광역시 및 전라남도\n  ⑤ 전라북도\n  ⑥ 대구광역시 및 경상북도\n  ⑦ 부산광역시, 울산광역시 및 경상남도\n  ⑧ 강원도\n \n  예) 주택건설지역이 경남 진주시일 경우 인근(기타)지역은 부산광역시, 울산광역시, 경상남도임.\n \n <예시> 공급세대수 순위 접수건수 순위내 경쟁률\n (미달세대수) 공급세대 및 경쟁률(미달세대) 산출식\n 100세대 1순위 해당지역 70 (Δ30) \n \n 공급세대 : 100세대\n \n 미달세대 : 100세대 - 70명 = 30세대\n 인근(기타)지역 10 (Δ20) \n \n 공급세대 : 1순위 해당지역 미달세대 30세대\n \n 미달세대 : 30세대 - 10명 = 20세대\n 2순위 해당지역 30 1.50 \n \n 공급세대 : 1순위 미달세대 20세대\n \n 경쟁률 : 20세대 ÷ 30명 = 1.50\n 인근(기타)지역 15 - \n \n 공급세대 : 0세대 (2순위 해당지역 미달세대가 없으므로 공급세대 없음)\n \n  예비입주자 선정 : 2순위 해당지역에서 입주자로 선정되지 않은 청약신청자(10명) 및 2순위 인근(기타)지역에서 입주자로 선정되지 않은 청약신청자(15명) 중 예비입주자를 선정ᴥhttps://www.applyhome.co.kr/ar/ard/selectSubscriptVocabularyView.do#voca1ᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '해당 주택건설지역 거주자 우선공급', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content="인근주택건설지역ᴥ주택공급은 동일 순위 내에서 해당 주택건설지역에 거주하는 청약신청자에게 우선적으로 공급되고 미달 시 무순위/잔여세대가 인근지역에 거주하는 청약신청자에게 공급됩니다. 다만, 수도권 내 대규모 택지개발지구 및 행정중심복합도시 예정지역(세종특별자치시)은 별도의 기준을 적용합니다.\n \n  인근지역의 범위\n  1. 서울특별시, 인천광역시 및 경기도 지역(이하 '수도권'이라 한다)\n  2. 대전광역시, 세종특별자치시 및 충청남도\n  3. 충청북도\n  4. 광주광역시 및 전라남도\n  5. 전라북도\n  6. 대구광역시 및 경상북도\n  7. 부산광역시, 울산광역시 및 경상남도\n  8. 강원도\n \n  * 다만, 세종특별자치시, 도청이전신도시, 혁신도시개발지구, 기업도시개발구역, 산업단지, 주한미군 이전지역, 위축지역에서 공급되는 주택은 해당 및 인근지역에 거주하지 아니하는 자도 청약 가능(주택공급에 관한 규칙 제4조제1항)\n \n  자세한 사항은 청약제도안내 > APT청약안내 > 당첨자선정을 참고하시기 바랍니다.ᴥhttps://www.applyhome.co.kr/ar/ard/selectSubscriptVocabularyView.do#voca1ᴥ청년주택드림청약통장", metadata={'category': '정보제공', '단어': '인근주택건설지역', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='오피스텔(생활숙박시설) 거주자 우선 분양ᴥ적용지역 : 투기과열지구 및 조정대상지역(청약과열지역)\n  거주자 우선 분양 신청 자격 : 분양 신고일 현재, 해당 오피스텔(생활숙박시설)을 공급하는 지역 거주자\n  단, 해당 오피스텔(생활숙박시설)에 1명당 1실만 신청 가능하며, 동일한 오피스텔(생활숙박시설)에 1명이 2실 이상을 거주자 우선 분양으로 신청할 경우, 거주자 우선 분양 신청내역 뿐만 아니라 해당 주택의 모든 청약신청 내역이 무효 처리\n  예시) 1인당 각 군(타입별) 1실 청약가능 오피스텔(생활숙박시설) (총 3개군으로 각 군별 1실씩 최대 3실 청약 가능)\n  가. 청약 유효\n  2군 : 1실 청약 (거주자 우선 분양신청)\n  1군, 3군 : 각 1실 청약 (총 2실, 거주자 우선 분양 신청 아님)\n  나. 청약 무효 (거주자 우선 분양 2실 이상 신청)\n  1군 및 2군 : 각 1실 청약 (총 2실, 거주자 우선 분양 신청)\n  3군 : 1실 청약 (일반청약 , 거주자 우선 분양 신청 아님)\n \n ※ 상기 예시는 사업주체의 청약조건에 따라 변경 될 수 있음\n \n  거주자 우선 분양 비율 (아래의 범위내에서 지자체장이 정함)\n  가. 분양물량이 100실 이상인 경우 : 분양물량의 10% ~ 20% 이하\n  나. 분양물량이 100실 미만인 경우 : 분양물량의 10% 이하\n \n ※ 거주자 우선 분양물량 소수점 발생시 절사하여 물량결정하되 최소 1개실 공급\n \n  당첨자 선정\n  가. 상기 "거주자 우선분양 비율"에 해당하는 분양물량을 거주자 우선분양 신청자를 대상으로 당첨자 선정(추첨)\n  나. 잔여 분양물량에 대하여 "가"에서 낙첨된 청약자와 거주자 우선분양 미신청자를 대상으로 당첨자 선정(추첨)\n \n  거주자 우선 분양 지역 거주자가 아닌 자가 "거주자 우선 분양"을 청약하여 "거주자 우선 분양"으로 당첨된 경우, 해당 오피스텔(생활숙박시설)의 계약은 불가합니다.\n \n * 관련법령 : 건축물의 분양에 관한 법률 시행령 제9조의2(거주자 우선 분양 기준)ᴥhttps://www.applyhome.co.kr/ar/ard/selectSubscriptVocabularyView.do#voca1ᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '오피스텔(생활숙박시설) 거주자 우선 분양', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='특별공급ᴥ주택의 공급방법은 일반공급, 우선공급 및 특별공급으로 구분합니다.(주택공급에 관한 규칙 제25조)\n \n 특별공급은 국가유공자, 장애인, 다자녀가구 등 정책적 배려가 필요한 사회계층 중 무주택자의 주택마련을 지원하기 위하여 주택 공급량의 일정비율을 특별공급 대상자에게 공급하는 제도입니다.\n \n 자세한 사항은 청약제도안내 > APT청약안내 > 특별공급을 참고하시기 바랍니다.ᴥhttps://www.applyhome.co.kr/ar/ara/selectSubscrptIntroSpetialView.doᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '특별공급', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='우선공급ᴥ일반인과 청약경쟁을 하되 특정조건을 갖춘 자에게 우선권을 주는 제도입니다. 특정조건에는 해당 주택건설지역 거주여부, 거주기간 등이 있습니다.\n \n  해당 주택건설지역 거주자 우선공급 : 주택공급 신청자 중 동일순위 안에서는 해당 주택건설지역의 거주자에 우선공급\n  투기방지를 위한 우선공급 : 해당 주택건설지역에 일정기간 이상 거주하고 있는 자에 우선공급\n  민영주택 등의 우선공급 : 행정구역 통합지역, 30세대 이상의 주상복합 건축물 건축 시 우선공급 (주택공급에 관한 규칙 제30조에서 34조 참조)\n  대규모 택지개발지구 등 주택의 우선공급 : 대규모(면적이 66만㎡ 이상) 택지개발지구 등에서 공급주택 중 일정비율 이상을 해당 주택건설지역 거주자에게 우선 공급\n  * 세부사항은 청약제도안내 > 주택청약 용어설명 > 대규모 택지개발지구 등 우선공급 참고ᴥhttps://www.applyhome.co.kr/ar/ard/selectSubscriptVocabularyView.do#voca1ᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '우선공급', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
#  Document(page_content='예비입주자ᴥ사업주체는 특별공급 대상 주택수(제35조부터 제46조까지의 규정에 따른 특별공급 대상 주택수의 합계)의 500% 이상(소수점 이하는 절상)의 예비입주자 선정(주택공급에 관한 규칙 제26조의2)하고, 일반공급(제27조 및 제28조의 규정의 순위에 따름) 대상 주택수의 500% 이상(소수점 이하는 절상)의 예비입주자를 각각 선정하여야 한다.\n \n  입주자(당첨자) 선정 후 입주자의 계약 미체결 및 부적격자 당첨 취소 등으로 인한 미계약 및 당첨취소 물량에 대하여 예비입주자에게 순번에 따라 공급하며 추첨의 방식으로 동호수를 배정합니다. 최초로 예비입주자를 입주자로 선정하는 경우로서 동호수를 배정받은 이후에 공급계약을 체결하지 않은 예비입주자도 당첨자로 관리합니다.\n  2023. 04. 01. 이후 모집공고 승인 주택에 선정된 예비입주자의 지위는 최초 공급계약 체결일부터 180일까지 유효합니다.ᴥhttps://www.applyhome.co.kr/ar/ard/selectSubscriptVocabularyView.do#voca1ᴥ청년주택드림청약통장', metadata={'category': '정보제공', '단어': '예비입주자', '정책명': '청년주택드림청약통장', 'source': './files/terms'}),
# ...
#  Document(page_content='국민취업지원제도ᴥ구직촉진수당 지급주기 중에 근로소득, 사업소득, 재산소득, 이전소득이 발생하면 소득금액 정도를 불문하고 반드시 의무적으로 신고를 해야 합니다.다만,법규(구직자취업촉진법 시행령 제2조제4항)에서 정한 소득이 아닌 소득에 대해서신고의무는 없으나수당 수급의 적법성 여부 판단 및 부정수급 방지 등을 위해신고하여 확인받도록 안내합니다.또한, 소득이 발생되었으나 신고하지 않았다는 이유만으로 부정수급 등 위법성이 있는 것은 아니며,신고하지 않은 소득이 수급받을 권리에 미치는 영향이 없으면별도의 조치는 없습니다.ᴥhttps://1350.moel.go.kr/home/hp/data/faqView.do?faq_idx=1000001689', metadata={'category': '정보제공', '정책명': '국민취업지원제도', 'source': './files/whole'}),
#  Document(page_content='국민취업지원제도ᴥ구직촉진수당을 분할 지급하기로 하여 월 지급액이 50만원 미만인 경우에도 월단위 지급액(50만원)을 지급정지 기준금액으로 적용합니다.(예시)2회차 수당을 25만원 분할 지급받기로 한 수급자가 2회차 지급주기 기간 중에 발생한 소득 합산액이 30만원인 경우, 지급정지되는 상한액 기준은 분할지급액 25만원이 아닌 50만원이 적용됨으로 해당 지급주기 기간의 구직촉진수당은 지급정지하지 않고 정상지급ᴥhttps://1350.moel.go.kr/home/hp/data/faqView.do?faq_idx=1000001690', metadata={'category': '정보제공', '정책명': '국민취업지원제도', 'source': './files/whole'}),
#  Document(page_content='국민취업지원제도ᴥ청년내일채움공제 가입기간과 취업성공수당 지급 기간과 일부 기간이 중복되더라도 중복되는 기간이 포함된 회차의 취업성공수당은 전액 지급되지 않습니다.- 근속 및 자산형성을 지원하는 유사 사업의 경우 수당 지급기간과 중복되는 기간에 대한 취업성공수당은 부지급다만, 일하는(기초생활보장) 수급가구 및 비수급근로빈곤층의 재활을 위한 자금 마련을 돕는 제도인 희망·내일·청년 키움통장, 청년저축계좌 보유자는 취업성공수당과 중복지급 가능ᴥhttps://1350.moel.go.kr/home/hp/data/faqView.do?faq_idx=1000001691', metadata={'category': '정보제공', '정책명': '국민취업지원제도', 'source': './files/whole'}),
#  Document(page_content="국민취업지원제도ᴥ취업이룸 통장은 신용불량 상태 등의 수급자를 위해 '구직촉진수당등'만이 입금되는 수급자전용 통장입니다.수급자의 구직촉진수당등이 압류되는 것을 방지하기 위해 구직촉진수당·취업활동비용·취업성공수당(조기취업성공수당 포함)만이 입금되고, 그 외의 금원은 입금이 차단됩니다.수급자 본인이라도 취업이룸 통장에 별도 금액을 입금할 수는 없습니다.ᴥhttps://1350.moel.go.kr/home/hp/data/faqView.do?faq_idx=1000001692", metadata={'category': '정보제공', '정책명': '국민취업지원제도', 'source': './files/whole'}),
#  Document(page_content='국민취업지원제도ᴥ네, 취업경험으로 인정합니다.현행 법령(구직자취업촉진법 시행규칙 제3조제1항제2호)에서「소득세법」 또는 「부가가치세법」에 따라 사업자등록을 한 기간도 취업경험으로 산정하도록 하고 있습니다.다만, 휴업신고를 하는 등 실제 사업을 하지 않았음이 확인된 기간 및 부동산임대업 중 근로자를 고용하지 않고 임대사무실도 두지 않은 기간은 제외합니다.ᴥhttps://1350.moel.go.kr/home/hp/data/faqView.do?faq_idx=1000001693', metadata={'category': '정보제공', '정책명': '국민취업지원제도', 'source': './files/whole'}),
#  Document(page_content='국민취업지원제도ᴥ네, 포함합니다.제대 군인(장교, 부사관) 등 공무원의 경우에도 취업한 기간으로 보아, 공무원 재직기간은 취업경험에 산입합니다.ᴥhttps://1350.moel.go.kr/home/hp/data/faqView.do?faq_idx=1000001839', metadata={'category': '정보제공', '정책명': '국민취업지원제도', 'source': './files/whole'}),
#  Document(page_content='국민취업지원제도ᴥ지역별 주택가격 차이를 감안하여 일반재산에서 지역별 공제금액을 제외합니다.(예시) 인천광역시 거주, 가구원 재산조회 결과 3억 5천만원의 재산 확인⇒ 대도시 기준, 6,900만원 공제하여 재산은 2억 8천 1백만원 확인부동산이 재산에 반영된 상태에서 임대보증금을 재산으로 산정하면 이중산정이 되므로,임대보증금은 재산가액에서 제외합니다.(예시) 2억 8천만원 부동산을 1억 5천만원 전세 임대보증금을 받고 임대⇒ 1억 5천만원 임대보증금은 재산으로 보지 않음ᴥhttps://1350.moel.go.kr/home/hp/data/faqView.do?faq_idx=1000001840', metadata={'category': '정보제공', '정책명': '국민취업지원제도', 'source': './files/whole'}),
#  Document(page_content='국민취업지원제도ᴥ네 그렇습니다.근로장학생으로 일한 기간은 취업한 기간으로 합산하여 취업경험에 포함합니다.ᴥhttps://1350.moel.go.kr/home/hp/data/faqView.do?faq_idx=1000001841', metadata={'category': '정보제공', '정책명': '국민취업지원제도', 'source': './files/whole'}),
#  Document(page_content='국민취업지원제도ᴥ소득산정에 포함하지 않습니다.이전소득은 국민연금, 사학퇴직연금, 공무원연금, 군인연금, 별정우체국연금 등 5개 공적연금만 반영합니다.ᴥhttps://1350.moel.go.kr/home/hp/data/faqView.do?faq_idx=1000001842', metadata={'category': '정보제공', '정책명': '국민취업지원제도', 'source': './files/whole'}),
#  Document(page_content='국민취업지원제도ᴥ국가·지자체가 보조하는 장학금 중 대학생이 근로를 대가로 받는 장학금은「소득세법」에 따른 비과세 소득에 해당하므로 소득 산정에서 제외합니다.다만, 방송대학·통신대학·방송통신대학 및 사이버대학, 기술대학 재학생은 위 내용에해당되지 않습니다.ᴥhttps://1350.moel.go.kr/home/hp/data/faqView.do?faq_idx=1000001843', metadata={'category': '정보제공', '정책명': '국민취업지원제도', 'source': './files/whole'}),
#  Document(page_content='국민취업지원제도ᴥ국민취업지원제도Ⅰ유형의 요건심사형과 선발형 비경활의 자격 판단의 기준이 되는 취업경험 요건의 고용보험 가입기간은 피보험기간을 인정하고 있어 실제 근무일자나 피보험단위 기간만을 인정하는 것은 아니고 취득일부터 이직일까지 전체 기간을 취업기간으로 인정합니다.ᴥhttps://1350.moel.go.kr/home/hp/data/faqView.do?faq_idx=1000001844', metadata={'category': '정보제공', '정책명': '국민취업지원제도', 'source': './files/whole'}),
#  Document(page_content='국민취업지원제도ᴥ워크넷 이외에 각종 온라인 구인사이트, 오프라인 구인기업 등에 대한 구직활동도 취업활동계획에 따라 취업희망직종을 대상으로 진행하는 경우 모두 구직활동으로 인정할 수 있습니다.ᴥhttps://1350.moel.go.kr/home/hp/data/faqView.do?faq_idx=1000001845', metadata={'category': '정보제공', '정책명': '국민취업지원제도', 'source': './files/whole'}),
#  Document(page_content='국민취업지원제도ᴥ취업이 사실상 확정되어 있는 경우에는 취업활동계획을 수립하는 것이 무의미하므로, 취업활동계획 수립 진행이 어렵습니다.다만, 취업여부가 불확실하여 변동 가능성이 있는 경우에는 취업활동계획 수립 상담을 지속할 수 있습니다.ᴥhttps://1350.moel.go.kr/home/hp/data/faqView.do?faq_idx=1000001846', metadata={'category': '정보제공', '정책명': '국민취업지원제도', 'source': './files/whole'}),
#  Document(page_content='국민취업지원제도ᴥ온라인 직업훈련은 훈련기간 등에 관계없이 훈련이 종료되는 일자가 포함된 지급주기의 구직활동으로만 인정하여 80%이상 수료하면 구직활동으로 인정합니다.(40시간 이상 훈련은 구직활동 2개, 40시간 미만은 구직활동 1개로 인정)단, 온라인 평가가 수료기준에 적용되면 수료율과 평가 이수 기준 모두 충족시 구직활동으로 인정합니다.ᴥhttps://1350.moel.go.kr/home/hp/data/faqView.do?faq_idx=1000001847', metadata={'category': '정보제공', '정책명': '국민취업지원제도', 'source': './files/whole'}),
#  Document(page_content="국민취업지원제도ᴥ「구직자취업촉진법」에서는 구직촉진수당 등을 부정수급하거나 부정수급을 공모한 자는 '1년 이하의 징역 또는 1천만원 이하의 벌금'에 처하도록 규정하고 있습니다.ᴥhttps://1350.moel.go.kr/home/hp/data/faqView.do?faq_idx=1000001848", metadata={'category': '정보제공', '정책명': '국민취업지원제도', 'source': './files/whole'}),
#  Document(page_content='기후동행카드ᴥ기후동행카드 정책 소개: 서울 권역 내 모든 대중교통과 따릉이 무제한 이용 가능한 대중교통 정기권ᴥ기후동행카드 온통 청년 url: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&frameYn=&bizId=R2024011819025&dtlOpenYn=&plcyTpOpenTy=&plcyCmprInfo=&srchWord=&chargerOrgCdAll=&srchAge=&trgtJynEmp=&trgtJynEmp=&srchSortOrder=1&pageUnit=12', metadata={'category': '정보제공', '정책명': '기후동행카드', 'source': './files/whole'}),
#  Document(page_content='기후동행카드ᴥ기후동행카드 지원 내용: □ 65,000원정기권(①서울 지역 내 지하철 ②서울시 면허 시내·마을버스 ③따릉이 무제한 이용 가능)\n□ 62,000원정기권(①서울 지역 내 지하철 ②서울시 면허 시내·마을버스)ᴥ기후동행카드 온통 청년 url: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&frameYn=&bizId=R2024011819025&dtlOpenYn=&plcyTpOpenTy=&plcyCmprInfo=&srchWord=&chargerOrgCdAll=&srchAge=&trgtJynEmp=&trgtJynEmp=&srchSortOrder=1&pageUnit=12', metadata={'category': '정보제공', '정책명': '기후동행카드', 'source': './files/whole'}),
#  Document(page_content='기후동행카드ᴥ기후동행카드 사업 운영 기간: 시범사업 사업기간 : 2024년 1월 27일(토) ~ 6월 30일(일)ᴥ기후동행카드 온통 청년 url: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&frameYn=&bizId=R2024011819025&dtlOpenYn=&plcyTpOpenTy=&plcyCmprInfo=&srchWord=&chargerOrgCdAll=&srchAge=&trgtJynEmp=&trgtJynEmp=&srchSortOrder=1&pageUnit=12', metadata={'category': '정보제공', '정책명': '기후동행카드', 'source': './files/whole'}),
#  Document(page_content='기후동행카드ᴥ기후동행카드 사업 신청 기간 반복 구분 코드: 2001ᴥ기후동행카드 온통 청년 url: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&frameYn=&bizId=R2024011819025&dtlOpenYn=&plcyTpOpenTy=&plcyCmprInfo=&srchWord=&chargerOrgCdAll=&srchAge=&trgtJynEmp=&trgtJynEmp=&srchSortOrder=1&pageUnit=12', metadata={'category': '정보제공', '정책명': '기후동행카드', 'source': './files/whole'}),
#  Document(page_content='기후동행카드ᴥ기후동행카드 사업 신청 기간: □ 1월 23일부터 모바일카드 다운로드 및 실물카드 판매 시작\n□ 1월 27일부터 서비스 본격 시작ᴥ기후동행카드 온통 청년 url: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&frameYn=&bizId=R2024011819025&dtlOpenYn=&plcyTpOpenTy=&plcyCmprInfo=&srchWord=&chargerOrgCdAll=&srchAge=&trgtJynEmp=&trgtJynEmp=&srchSortOrder=1&pageUnit=12', metadata={'category': '정보제공', '정책명': '기후동행카드', 'source': './files/whole'}),
#  Document(page_content='기후동행카드ᴥ기후동행카드 연령: 제한없음ᴥ기후동행카드 온통 청년 url: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&frameYn=&bizId=R2024011819025&dtlOpenYn=&plcyTpOpenTy=&plcyCmprInfo=&srchWord=&chargerOrgCdAll=&srchAge=&trgtJynEmp=&trgtJynEmp=&srchSortOrder=1&pageUnit=12', metadata={'category': '정보제공', '정책명': '기후동행카드', 'source': './files/whole'}),
#  Document(page_content='기후동행카드ᴥ기후동행카드 거주지 및 소득: 서울 시민 누구나ᴥ기후동행카드 온통 청년 url: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&frameYn=&bizId=R2024011819025&dtlOpenYn=&plcyTpOpenTy=&plcyCmprInfo=&srchWord=&chargerOrgCdAll=&srchAge=&trgtJynEmp=&trgtJynEmp=&srchSortOrder=1&pageUnit=12', metadata={'category': '정보제공', '정책명': '기후동행카드', 'source': './files/whole'}),
#  Document(page_content='기후동행카드ᴥ기후동행카드 추가 단서 사항: □ 이용범위: 서울지역 지하철, 서울시 면허 시내·마을버스, 따릉이\n□ 이용제외: 신분당선, 서울지역 외 지하철, 광역/공항버스, 타 지역 면허버스\n※ 버스의 경우 서울시 면허 버스는 서울지역 외에서 승하차하더라도 기후동행카드 사용가능\n※ 지하철의 경우 서울지역 내 역에서 승차 후 서울지역 외 역에서 하차할 경우 기후동행카드 사용불가ᴥ기후동행카드 온통 청년 url: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&frameYn=&bizId=R2024011819025&dtlOpenYn=&plcyTpOpenTy=&plcyCmprInfo=&srchWord=&chargerOrgCdAll=&srchAge=&trgtJynEmp=&trgtJynEmp=&srchSortOrder=1&pageUnit=12', metadata={'category': '정보제공', '정책명': '기후동행카드', 'source': './files/whole'}),
#  Document(page_content='기후동행카드ᴥ기후동행카드 신청 절차: □ 모바일 카드\n[모바일 티머니 앱 다운로드] ▷ [회원가입] ▷ [기후동행카드 발급 및 충전]\n□ 실물카드\n[서울교통공사(1~8호선) 고객안전실 및 역사 인근 편의점 방문] ▷ [기후동행카드 구매] ▷ [티머니 카드&페이 홈페이지 등록] ▷ [구매한 카드를 역사 내 무인충전기에서 충전]ᴥ기후동행카드 온통 청년 url: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&frameYn=&bizId=R2024011819025&dtlOpenYn=&plcyTpOpenTy=&plcyCmprInfo=&srchWord=&chargerOrgCdAll=&srchAge=&trgtJynEmp=&trgtJynEmp=&srchSortOrder=1&pageUnit=12', metadata={'category': '정보제공', '정책명': '기후동행카드', 'source': './files/whole'}),
#  Document(page_content='기후동행카드ᴥ기후동행카드 참고 사이트 주소1: https://news.seoul.go.kr/traffic/archives/510651ᴥ기후동행카드 온통 청년 url: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&frameYn=&bizId=R2024011819025&dtlOpenYn=&plcyTpOpenTy=&plcyCmprInfo=&srchWord=&chargerOrgCdAll=&srchAge=&trgtJynEmp=&trgtJynEmp=&srchSortOrder=1&pageUnit=12', metadata={'category': '정보제공', '정책명': '기후동행카드', 'source': './files/whole'}),
#  Document(page_content='기후동행카드ᴥ기후동행카드 주관 부처명: 서울시ᴥ기후동행카드 온통 청년 url: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&frameYn=&bizId=R2024011819025&dtlOpenYn=&plcyTpOpenTy=&plcyCmprInfo=&srchWord=&chargerOrgCdAll=&srchAge=&trgtJynEmp=&trgtJynEmp=&srchSortOrder=1&pageUnit=12', metadata={'category': '정보제공', '정책명': '기후동행카드', 'source': './files/whole'}),
#  Document(page_content='기후동행카드ᴥ기후동행카드 운영 기관명: 서울시ᴥ기후동행카드 온통 청년 url: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&frameYn=&bizId=R2024011819025&dtlOpenYn=&plcyTpOpenTy=&plcyCmprInfo=&srchWord=&chargerOrgCdAll=&srchAge=&trgtJynEmp=&trgtJynEmp=&srchSortOrder=1&pageUnit=12', metadata={'category': '정보제공', '정책명': '기후동행카드', 'source': './files/whole'}),
#  Document(page_content="기후동행카드ᴥ기후동행카드 기타 사항: ※ 결제수단 : 모바일(계좌이체- 향후 결제수단 확대 예정), 실물카드(현금결제, 실물카드는 3,000원으로 별도 구매 필요, 최초 구매 후 매달 충전 사용)\n※ 실물카드 이용자는 반드시 '티머니 카드&페이' 홈페이지에 카드 등록 필요(1인 1카드 원칙)\n->카드 미등록 시 환불 및 따릉이 이용 불가ᴥ기후동행카드 온통 청년 url: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&frameYn=&bizId=R2024011819025&dtlOpenYn=&plcyTpOpenTy=&plcyCmprInfo=&srchWord=&chargerOrgCdAll=&srchAge=&trgtJynEmp=&trgtJynEmp=&srchSortOrder=1&pageUnit=12", metadata={'category': '정보제공', '정책명': '기후동행카드', 'source': './files/whole'}),
#  Document(page_content='기후동행카드ᴥ기후동행카드 정책 분야: 복지·문화 분야ᴥ기후동행카드 온통 청년 url: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&frameYn=&bizId=R2024011819025&dtlOpenYn=&plcyTpOpenTy=&plcyCmprInfo=&srchWord=&chargerOrgCdAll=&srchAge=&trgtJynEmp=&trgtJynEmp=&srchSortOrder=1&pageUnit=12', metadata={'category': '정보제공', '정책명': '기후동행카드', 'source': './files/whole'}),
#  Document(page_content='기후동행카드ᴥ기후동행카드 온통 청년 url: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&frameYn=&bizId=R2024011819025&dtlOpenYn=&plcyTpOpenTy=&plcyCmprInfo=&srchWord=&chargerOrgCdAll=&srchAge=&trgtJynEmp=&trgtJynEmp=&srchSortOrder=1&pageUnit=12ᴥ기후동행카드 온통 청년 url: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&frameYn=&bizId=R2024011819025&dtlOpenYn=&plcyTpOpenTy=&plcyCmprInfo=&srchWord=&chargerOrgCdAll=&srchAge=&trgtJynEmp=&trgtJynEmp=&srchSortOrder=1&pageUnit=12', metadata={'category': '정보제공', '정책명': '기후동행카드', 'source': './files/whole'}),
#  Document(page_content='기후동행카드ᴥ○ 이용 권종으로는 따릉이 포함여부에 따라 ▲6만 5천원권, ▲6만 2천원권 2종으로 출시되므로 사용패턴에 따라 자유롭게 선택하여 구매할 수 있습니다.ᴥhttps://news.seoul.go.kr/traffic/archives/511551', metadata={'category': '정보제공', '정책명': '기후동행카드', 'source': './files/whole'}),
#  Document(page_content='기후동행카드ᴥ○ 서비스 구간은 서울지역 내 지하철, 심야버스를 포함한 서울시 면허 시내ㆍ마을버스와 공공자전거인 따릉이가 포함됩니다. 신분당선 및 타 시ㆍ도 면허버스, 광역버스는 제외됩니다. ○ 다만, 서울 외 지역이라 승차는 할 수 없지만 예외적으로 김포골드라인 전 구간(양촌~김포공항역), 진접선 전 구간(별내별가람~진접역), 5호선 하남구간(미사~하남검단산역), 7호선 인천구간(석남~까치울역)에서는 하차는 가능하니 이용에 참고 바랍니다. ○ 구체적인 서비스 구간은 서울시 홈페이지에서 확인할 수 있습니다. - 서울시 홈페이지(https://www.seoul.go.kr/main/index.jsp) → 분야별정보 → 교통 → 버스ㆍ지하철ㆍ택시 → 기후동행카드ᴥhttps://news.seoul.go.kr/traffic/archives/511551', metadata={'category': '정보제공', '정책명': '기후동행카드', 'source': './files/whole'}),
#  Document(page_content='기후동행카드ᴥ○ 서울지역 내에서 승차했더라도, 서울지역을 벗어난 역에서는 기후동행카드를 태그하여 하차할 수 없습니다. 이 경우, 하차역에서 역무원을 호출하여 별도 요금(승차역~하차역 이용요금)을 추가로 납부해야 합니다. ○ 또한, 하차 미태그 처리되어 패널티도 부과되니, 카드 사용 전 이용가능한 구간인지를 반드시 확인해야 합니다.ᴥhttps://news.seoul.go.kr/traffic/archives/511551', metadata={'category': '정보제공', '정책명': '기후동행카드', 'source': './files/whole'}),
#  Document(page_content='기후동행카드ᴥ○ 평소 이용하는 버스의 면허지역은 포털사이트(네이버 등) 검색을 통해 간편히 확인할 수 있습니다. ○ 또한, 이용가능한 버스 노선의 전면 유리창과 하차문에는 안내문이 부착되어 있으므로 현장에서도 확인할 수 있습니다.ᴥhttps://news.seoul.go.kr/traffic/archives/511551', metadata={'category': '정보제공', '정책명': '기후동행카드', 'source': './files/whole'}),
#  Document(page_content='기후동행카드ᴥ○ 간선버스 요금 적용을 받는 서울02, 서울04, 서울05 동행버스에서는 사용할 수 있습니다.ᴥhttps://news.seoul.go.kr/traffic/archives/511551', metadata={'category': '정보제공', '정책명': '기후동행카드', 'source': './files/whole'}),
#  Document(page_content='기후동행카드ᴥ○ 모바일카드는 안드로이드 휴대전화(OS12 이상 버전)에서만 이용가능합니다. ‘구글플레이’에서 ‘모바일티머니’ 앱을 무료로 다운로드하고, 회원가입 후 메인 화면에서 기후동행카드 발급을 선택하여 계좌이체 방식으로 충전할 수 있습니다.ᴥhttps://news.seoul.go.kr/traffic/archives/511551', metadata={'category': '정보제공', '정책명': '기후동행카드', 'source': './files/whole'}),
#  Document(page_content='기후동행카드ᴥ○ 중복 결제는 되지 않습니다. 다만, 시스템 충돌 방지를 위해 다른 모바일 교통카드 해지가 필요합니다. 모바일 기후동행카드 발급 시, “기후동행카드는 ㅇㅇ페이 티머니 해지 후 발급/사용 가능합니다”라는 안내가 뜨면 ‘해지하기’ 버튼을 눌러 해지할 수 있습니다. ○ ‘모바일티머니’앱에서 다른 교통카드를 이용 중인 경우, 기후동행카드를 ‘주 교통카드’로 설정한 후 이용하면 됩니다.ᴥhttps://news.seoul.go.kr/traffic/archives/511551', metadata={'category': '정보제공', '정책명': '기후동행카드', 'source': './files/whole'}),
#  Document(page_content='기후동행카드ᴥ○ ‘실물카드’ 판매는 서울교통공사에서 운영하는 1호선 서울역에서 청량리역 구간, 2호선에서 8호선 서울지역 구간 역사 고객안전실에서 현금 3천원에 구매할 수 있습니다. 또한, 9호선 역사 내 편의점과 신림선, 우이신설선 인근 편의점에서는 현금 및 신용카드로 3천원에 구매할 수 있습니다. ○ 구체적인 판매처는 서울시 홈페이지에서 확인할 수 있습니다. - 서울시 홈페이지(https://www.seoul.go.kr/main/index.jsp) → 분야별정보 → 교통 → 버스ㆍ지하철ㆍ택시 → 기후동행카드 ○ 서울시는 수시로 판매처 재고량을 확인하여, 물량을 공급하고 있습니다. 다만, 각 판매처별 배송일정이 달라 실시간으로 일괄 확인하기 어렵습니다. 번거로우시더라도 구매를 원하는 역사 및 편의점에 재고 현황을 사전에 확인한 후 방문하시기 바랍니다.ᴥhttps://news.seoul.go.kr/traffic/archives/511551', metadata={'category': '정보제공', '정책명': '기후동행카드', 'source': './files/whole'}),
#  Document(page_content='기후동행카드ᴥ○ 등록된 ‘실물카드’로만 ‘따릉이 이용’ 및 ‘환불’이 가능하며, 추후 개선될 서비스도 등록된 카드에 한해 적용되니 반드시 등록이 필요합니다. 또한 카드를 등록한 경우, 이용내역 조회가 가능하고 티머니 카카오채널을 통해 다양한 정보를 안내받을 수 있으므로 더욱 편리한 이용이 가능합니다. ○ ‘티머니카드&페이’ 홈페이지 → 기후동행카드 이용안내 → 실물 기후동행카드 ‘카드등록 바로가기’ᴥhttps://news.seoul.go.kr/traffic/archives/511551', metadata={'category': '정보제공', '정책명': '기후동행카드', 'source': './files/whole'}),
#  Document(page_content='기후동행카드ᴥ○ 기후동행카드는 역사 내 충전단말기에서 현금으로만 충전이 가능합니다. ○ 충전 가능한 역사는 서울교통공사 운영 1호선 서울역에서 청량리 구간, 서울지역 2호선에서 8호선, 9호선, 우이신설선, 신림선입니다. ○ 구체적인 충전처는 서울시 홈페이지에서 확인할 수 있습니다. - 서울시 홈페이지(https://www.seoul.go.kr/main/index.jsp) → 분야별정보 → 교통 → 버스ㆍ지하철ㆍ택시 → 기후동행카드ᴥhttps://news.seoul.go.kr/traffic/archives/511551', metadata={'category': '정보제공', '정책명': '기후동행카드', 'source': './files/whole'}),
#  Document(page_content='기후동행카드ᴥ○ 기후동행카드는 1인 1매 사용이 원칙이므로, 다인승 결제는 불가능합니다.ᴥhttps://news.seoul.go.kr/traffic/archives/511551', metadata={'category': '정보제공', '정책명': '기후동행카드', 'source': './files/whole'}),
#  ...]

# %%
tmp4 = list(df_to_doc(process_df,
                      './files',
                      column_list = ['정책명', '정책 소개', '연령', '전공', '취업 상태', '학력', '거주지 및 소득', '추가 단서 사항', '참여 제한 대상'],
                      source_dict = {'category':'자격요건'},
                      metadata_columns=['정책명', '연령', '전공', '취업 상태', '학력', '거주지 및 소득', '참여 제한 대상']
                      ))

# %%
len(tmp)
# Out:
# 1131

# %%
vectorstore = Chroma.from_documents(tmp, embeddings, persist_directory='./chroma_db2')

# %%
vectorstore = Chroma(persist_directory="./chroma_db2", embedding_function=embeddings)

# %% [markdown]
# ## Self-Querying 사용

# %% [markdown]
# self-querying 설명
# - https://python.langchain.com/docs/modules/data_connection/retrievers/self_query
# - integrations : https://python.langchain.com/docs/integrations/retrievers/self_query/
# - chroma self-querying : https://github.com/langchain-ai/langchain/blob/master/docs/docs/integrations/retrievers/self_query/chroma_self_query.ipynb
#
# source code :
# - from_llm source : https://github.com/langchain-ai/langchain/blob/master/libs/langchain/langchain/retrievers/self_query/base.py
#
# Chroma.as_retriever source code
# - https://github.com/langchain-ai/langchain/blob/master/libs/community/langchain_community/vectorstores/chroma.py
# - as_retriever source : https://github.com/langchain-ai/langchain/blob/master/libs/core/langchain_core/vectorstores.py
#
# chroma self query source code
# - https://github.com/langchain-ai/langchain/blob/master/libs/langchain/langchain/retrievers/self_query/chroma.py
#
# langchain chroma documentation : https://api.python.langchain.com/en/latest/vectorstores/langchain_community.vectorstores.chroma.Chroma.html#langchain_community.vectorstores.chroma.Chroma.as_retriever

# %%
from langchain.chains.query_constructor.base import AttributeInfo
from langchain.retrievers.self_query.base import SelfQueryRetriever
from langchain_openai import OpenAI, ChatOpenAI

# %%
retriever = vectorstore.as_retriever(search_type="mmr", verbose=True)
type(retriever)
# Out:
# langchain_core.vectorstores.VectorStoreRetriever

# %%
metadata_field_info = [
    AttributeInfo(
        name="category",
        description="classification according to Query intent",
        type="string",
    ),
    AttributeInfo(
        name="정책명",
        description="The policy name related to passage",
        type="integer",
    ),
    AttributeInfo(
        name="단어",
        description="The terms explained by the passage",
        type="string",
    ),
]
document_content_description = "Explanation of terms related to policy"
llm = ChatOpenAI(
            model_name="gpt-3.5-turbo",
            temperature=0,
            )
retriever = SelfQueryRetriever.from_llm(
    llm, vectorstore, document_content_description, metadata_field_info, verbose=True
    # llm, vectorstore.as_retriever(search_type='mmr', verbose=True), document_content_description, metadata_field_info, verbose=True
)

# %% [markdown]
# self query retreiver
# - source code : https://github.com/langchain-ai/langchain/blob/master/libs/langchain/langchain/retrievers/self_query/base.py
# - document : https://api.python.langchain.com/en/latest/retrievers/langchain.retrievers.self_query.base.SelfQueryRetriever.html
# - search type : https://api.python.langchain.com/en/latest/vectorstores/langchain_community.vectorstores.chroma.Chroma.html#langchain_community.vectorstores.chroma.Chroma.as_retriever

# %%
print(type(retriever)) # 
print(dir(retriever))
# Out:
# <class 'langchain.retrievers.self_query.base.SelfQueryRetriever'>
# ['Config', 'InputType', 'OutputType', '__abstractmethods__', '__annotations__', '__class__', '__class_getitem__', '__class_vars__', '__config__', '__custom_root_type__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__exclude_fields__', '__fields__', '__fields_set__', '__format__', '__ge__', '__get_validators__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__include_fields__', '__init__', '__init_subclass__', '__iter__', '__json_encoder__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__or__', '__orig_bases__', '__parameters__', '__post_root_validators__', '__pre_root_validators__', '__pretty__', '__private_attributes__', '__reduce__', '__reduce_ex__', '__repr__', '__repr_args__', '__repr_name__', '__repr_str__', '__rich_repr__', '__ror__', '__schema_cache__', '__setattr__', '__setstate__', '__signature__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__try_update_forward_refs__', '__validators__', '__weakref__', '_abatch_with_config', '_abc_impl', '_acall_with_config', '_aget_docs_with_query', '_aget_relevant_documents', '_atransform_stream_with_config', '_batch_with_config', '_calculate_keys', '_call_with_config', '_copy_and_set_values', '_decompose_class', '_enforce_dict_if_root', '_expects_other_args', '_get_docs_with_query', '_get_relevant_documents', '_get_value', '_init_private_attributes', '_is_protocol', '_iter', '_lc_kwargs', '_new_arg_supported', '_prepare_query', '_transform_stream_with_config', 'abatch', 'aget_relevant_documents', 'ainvoke', 'assign', 'astream', 'astream_events', 'astream_log', 'atransform', 'batch', 'bind', 'config_schema', 'config_specs', 'configurable_alternatives', 'configurable_fields', 'construct', 'copy', 'dict', 'from_llm', 'from_orm', 'get_graph', 'get_input_schema', 'get_lc_namespace', 'get_name', 'get_output_schema', 'get_prompts', 'get_relevant_documents', 'input_schema', 'invoke', 'is_lc_serializable', 'json', 'lc_attributes', 'lc_id', 'lc_secrets', 'llm_chain', 'map', 'metadata', 'name', 'output_schema', 'parse_file', 'parse_obj', 'parse_raw', 'pick', 'pipe', 'query_constructor', 'schema', 'schema_json', 'search_kwargs', 'search_type', 'stream', 'structured_query_translator', 'tags', 'to_json', 'to_json_not_implemented', 'transform', 'update_forward_refs', 'use_original_query', 'validate', 'validate_translator', 'vectorstore', 'verbose', 'with_config', 'with_fallbacks', 'with_listeners', 'with_retry', 'with_types']

# %%
# retriever.get_relevant_documents("금리가 뭐야?")
# retriever.get_relevant_documents("금리가 뭐야?", metadata={'category':'정보제공'})
# retriever.get_relevant_documents("[category:정보제공] 금리가 뭐야?")
# retriever.get_relevant_documents("[category:절차문의] 금리가 뭐야?")

# retriever.get_relevant_documents("[category:정보제공] 정책 중에 전세 자금 대출 관련 정책이 있으면 추천해줘.")
retriever.get_relevant_documents("청년도약계좌 자격요건을 알려줘.")
# Out:
# [Document(page_content='청년도약계좌ᴥ가입신청 시 제출할 서류는 없습니다.단, 가입요건 충족여부 확인 과정에서 전산정보만으론 정보확인이 불가한 경우, 아래 서류제출을 요청할 수 있습니다.가입요건서류제출 대상자제출서류나이만34세 초과 병역이행기간 확정 불가자군경력증명서, 병적증명서*발급 : 정부24>기타요청사항지방병무청, 병무청 콜센터개인소득육아휴직급여 및 육아휴직수당 수령자ㆍ일반근로자: 육아휴직급여 지급결정 통지서, 신분증 사본(주민번호 13자리 확인 必)ㆍ공무원: 휴직증명서, 급여명세서(육아휴직수당 내역 포함), 신분증 사본(주민번호 13자리 확인 必)가구원확정주민등록표등본에 신청인과의 관계가 불분명한 세대원이 있는 신청자가족관계증명서* 발급처 : 법원 전자가족관계등록시스템최신화①등본에 조회된 가구원이 사망 등으로 제외가 필요한 경우②신청자가 부양중인 조(외조)부모가 있는 신청자상세서류 별도확인소득--ᴥhttps://blog.naver.com/mltmkr/223359281452', metadata={'category': '정보제공', 'source': './files/whole', '정책명': '청년도약계좌'}),
#  Document(page_content='청년도약계좌ᴥ청년도약계좌는 국세청에서 제공하는 전산 정보를 바탕으로 개인소득 요건 충족 여부를 확인합니다.※ 육아휴직직급여 및 육아휴직수당 외엔 별도 증빙서류 제출 불필요 개인소득 요건 확인의 각 기준은 아래와 같습니다.1.기준연도 : 계좌개설일 전년도 또는 전전년도(국세청에서 소득액 확정 전)2024.7월 가입신청 시, 2023년도 소득을 기준으로 가입요건 확인2024.6월 가입신청 시, 2022년도 소득을 기준으로 가입요건 확인2. 산정기준 : 총급여(근로소득), 종합소득, 사업소득(연금소득 및 종교인소득 포함)3. 가입요건 : 아래 3가지 조건을 동시 충족구분가입요건 상세1가입요건 확인 기준연도에 과세소득이 존재2가입요건 확인 기준연도에 총급여액이 7,500만원 이하3가입요건 확인 기준연도에 종합소득이 6,300만원 이하4. 금액확인 : 국세청홈택스>국세증명·사업자등록·세금관련 신청/신고>즉시발급 증명>소득확인증명서(청년도약계좌 가입 및 과세특례 신청용)★ 소득상세금액은 서민금융진흥원에서 확인·수정이 불가합니다.★ 소득신고 오류 등으로 소득확인증명서 상 개인소득 수정(이의신청)이 필요한 경우, 국세청에 수정신고·처리완료 후 청년도약계좌에 재신청하시면 됩니다.ᴥhttps://blog.naver.com/mltmkr/223359281452', metadata={'category': '정보제공', 'source': './files/whole', '정책명': '청년도약계좌'}),
#  Document(page_content='청년도약계좌ᴥ청년도약계좌 거주지 및 소득: [개인소득]\n□ 직전 과세기간의 총급여액이 7,500만원 이하이며, 종합소득과세표준에 합산되는 종합소득금액이 6,300만원 이하인 경우 (단, 육아휴직급여, 육아휴직수당 외에 비과세 소득만 있는 경우는 제외)\n ※ 직전 과세기간의 소득이 확정되지 않은 기간에 소득을 확인한 경우 전전년도 소득으로 인정\n[가구소득]\n□ 가구원 수에 따른 기준 중위소득 180% 이하에 해당하는 자\n ※ 직전 과세기간의 소득이 확정되지 않은 기간에 소득을 확인한 경우 전전년도 소득으로 인정\n ※가구원은 청년 본인과 본인의 주민등록표 등본상 배우자, 부모, 자녀, 형제·자매(미성년자)를 기준으로 판단\n[금융소득종합과세]\n가입일이 속한 과세기간의 직전 3개년도 중 1회 이상 금융소득종합과세 대상자에 해당하지 않는 자ᴥhttps://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&frameYn=&bizId=R2024010818565&dtlOpenYn=&plcyTpOpenTy=&plcyCmprInfo=&srchWord=&chargerOrgCdAll=&srchAge=&trgtJynEmp=&trgtJynEmp=&srchSortOrder=1&pageUnit=12', metadata={'category': '정보제공', 'source': './files/whole', '정책명': '청년도약계좌'}),
#  Document(page_content='청년도약계좌ᴥ□ (결과확인) 가입(계좌개설) 가능 여부는 가입신청 후 3~4주 내 발표되며 가입 가능 여부에 따라 아래와 같이 구분하여 안내됩니다. ㅇ (가입 가능자) 청년도약계좌 가입을 신청한 은행에서 안내되며 해당 은행 앱을 통해 계좌 개설을 진행하여 주시기 바랍니다. ㅇ (가입 불가능자) 서민금융진흥원에서 안내되며, 가입요건 충족 후 은행 앱을 통해 재신청하여 주시기 바랍니다. * 신청 및 결과발표 상세일정은 서민금융진흥원 홈페이지 공지사항을 참고하여 주시기 바랍니다. □ (가입불가 사유) 보통 ① 또는 ②의 사유로 인해 가입이 제한됩니다. 청년도약계좌 가입을 희망하시는 경우 가입요건을 충족 후 다음 가입신청 기간에 재신청하여 주시기 바랍니다.① (소득요건 미충족) 가입요건 중 개인소득요건 또는 가구소득요건을 충족하지 않는 경우 청년도약계좌 가입이 불가능합니다. ※ 자세한 내용은 (가입요건), (개인소득), (가구소득) 질문 답변 참조② (가입절차 미완료) 제출서류가 요건에 미비*하거나 가구원 동의가 미완료된 경우, 진행이 자동 종료되어 청년도약계좌 가입이 불가합니다. * 제출서류 일부 누락, 서류 불인정(내용확인 불가, 열람용 제출 등), 심사정보 오기재 등ᴥhttps://blog.naver.com/mltmkr/223359281452', metadata={'category': '정보제공', 'source': './files/whole', '정책명': '청년도약계좌'})]

# %%
# retriever.get_relevant_documents("[category:관련없음] 마산치매안심센터 증축을 위한 설계공모의 입선작을 창원이 뽑은 건 언제야")
# retriever.get_relevant_documents("마산치매안심센터 증축을 위한 설계공모의 입선작을 창원이 뽑은 건 언제야", metadata={'category': 'x'})    
# retriever.get_relevant_documents("마산치매안심센터 증축을 위한 설계공모의 입선작을 창원이 뽑은 건 언제야")
# Out:
# [Document(page_content='창원 청년 프로젝트ᴥ참가신청서 및 제출서류 작성 후 담당자 이메일로 송부(clouds@chari.re.kr)ᴥ□ 제출서류\n① 참가신청서 1부 \n② 사업계획서 1부 \n③ 개인정보동의서 1부\n④ 청렴이행서약서 1부ᴥㅁ 선발일정 및 방법(안)\n- 모집 및 신청 : 2.15.(목) ~ 3.13.(수)\n- 1차 심사(서면) : 3.14.(목)\n- 1차 심사 결과발표 : 3.15.(금)\n- 2차 심사(면접) : 3.23.(토)\n- 최종선정 결과공고 : 3.25.(월)\n ※ 심사 합격자에 한하여 개별 통보(유선전화) \n※ 세부 일정은 추진사항에 따라 변경될 수 있음ᴥ-ᴥhttps://www.changwon.go.kr/youth/05085/05105.web?amode=view&idx=77ᴥ', metadata={'category': '절차문의', '정책명': '창원 청년 프로젝트'}),
#  Document(page_content='2024년 첫만남 이용권ᴥ□ 행정복지센터 및 복지로24, 정부24ᴥ-ᴥ-ᴥ-ᴥhttps://www.mohw.go.kr/board.es?mid=a10411010100&bid=0019ᴥ', metadata={'category': '절차문의', '정책명': '2024년 첫만남 이용권'}),
#  Document(page_content='산모·신생아 건강관리 지원사업ᴥ방문, 인터넷ᴥ사회보장급여(사회서비스이용권) 신청(변경)서 또는 임신서비스 통합처리 신청서 각 1부ᴥ-ᴥ-ᴥ-ᴥ-', metadata={'category': '절차문의', '정책명': '산모·신생아 건강관리 지원사업'}),
#  Document(page_content='경남창조경제혁신센터 신규입주기업 모집ᴥ담당자 E-MAIL 제출 : hjyh909@ccei.krᴥ-ᴥ-ᴥhttps://ccei.creativekorea.or.kr/gyeongnam/allim/allim_view.do?div_code=1&no=13695ᴥ-ᴥ-', metadata={'category': '절차문의', '정책명': '경남창조경제혁신센터 신규입주기업 모집'})]

# %%
metadata_field_info = [
    AttributeInfo(
        name="category",
        # description="classification according to Query intent",
        description="절차문의", # 기능을 쪼개서 챗봇을 사용할 경우. 이렇게 쓰면(기능별로 카테고리명을 써주면 ) 더 잘 나오는 것 같기도..
        type="string",
    ),
    AttributeInfo(
        name="정책명",
        description="Policy name of the procedure indicated in the passage",
        type="integer",
    )
]
document_content_description = "Explanation of the procedure related to policy"
llm = ChatOpenAI(
            model_name="gpt-3.5-turbo",
            temperature=0,
            )
retriever = SelfQueryRetriever.from_llm(
    llm, vectorstore, document_content_description, metadata_field_info, verbose=True
)

# %%
# retriever.get_relevant_documents("기후동행카드는 어떻게 신청해?")
# retriever.get_relevant_documents("[category:절차문의] 기후동행카드는 어떻게 신청해?")
# retriever.get_relevant_documents("[category:절차문의][정책명:기후동행카드] 기후 동행 카드는 어떻게 신청해?")

# retriever.get_relevant_documents("[category:절차문의] 국민취업제도는 어떻게 신청해?")
# retriever.get_relevant_documents("[category:절차문의] 국취제는 어떻게 신청해?")
# retriever.get_relevant_documents("[category:절차문의][정책명:국민취업지원제도] 국취제는 어떻게 신청해?")

# retriever.get_relevant_documents("청년도약계좌는 어떻게 신청해?")
# retriever.get_relevant_documents("청년도약계좌는 어떻게 신청해?", metadata={'category':'절차문의', '정책명':'청년도약계좌'})
# retriever.get_relevant_documents("[category:절차문의] 청년도약계좌는 어떻게 신청해?")
# retriever.get_relevant_documents("[category:정보제공] 청년도약계좌는 어떻게 신청해?")
# retriever.get_relevant_documents("[category:절차문의][정책명:청년도약계좌] 청년도약계좌는 어떻게 신청해?")

# retriever.get_relevant_documents("버팀목전세자금대출은 어떻게 신청해?")
retriever.get_relevant_documents("버팀목전세자금대출은 뭐야?")
# Out:
# [Document(page_content='청년전용 버팀목전세자금ᴥ청년전용 버팀목전세자금 정책 소개: 전세자금이 부족한 청년들에게 청년전용 버팀목 전세자금을 대출ᴥhttps://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&frameYn=&bizId=R2024010918589&dtlOpenYn=&plcyTpOpenTy=&plcyCmprInfo=&srchWord=&chargerOrgCdAll=&srchAge=&trgtJynEmp=&trgtJynEmp=&srchSortOrder=1&pageUnit=12', metadata={'category': '정보제공', 'source': './files/whole', '정책명': '청년전용 버팀목전세자금'}),
#  Document(page_content='청년전용 버팀목전세자금ᴥ○ 대출 실행 후 아래의 기일 중 늦을 날로부터 14일 이내에 대출계약철회 가능 1) 대출계약서류를 제공받은 날 2) 대출계약체결일 3) 대출실행일 4) 사후자가산심사결과 부적격 확정통지일 - 대출계약 철회는 채무자가 철회기한 이내에 원금과 이자 및 부대비용을 전액 반환한 때에 효력이 발생○ 대출계약 철회권의 효력이 발생한 이후에는 철회권 행사 취소 불가ᴥhttps://nhuf.molit.go.kr/FP/FP05/FP0502/FP05020303.jsp?gotoPage=1', metadata={'category': '정보제공', 'source': './files/whole', '정책명': '청년전용 버팀목전세자금'}),
#  Document(page_content='집단전세보증ᴥ공사의 사전승인을 받은 임대사업장 입주예정자의 임차중도금 및 잔금 대출을 위한 공사의 담보(보증서) 제공 시 소득 및 부채 수준에 따른 상환능력 평가를 생략할 수 있는 상품ᴥhttps://www.hf.go.kr/ko/sub02/sub02_01_03.doᴥ청년전용 버팀목전세자금', metadata={'category': '정보제공', 'source': './files/terms', '단어': '집단전세보증', '정책명': '청년전용 버팀목전세자금'}),
#  Document(page_content='청년전용 버팀목전세자금ᴥ○ 타행간 대환 불가ᴥhttps://nhuf.molit.go.kr/FP/FP05/FP0502/FP05020303.jsp?gotoPage=1', metadata={'category': '정보제공', 'source': './files/whole', '정책명': '청년전용 버팀목전세자금'})]

# %%
retriever.get_relevant_documents("국민취업제도 자격요건을 알려줘.")
# Out:
# [Document(page_content='국민취업지원제도ᴥ주민등록표에 등재된① 신청인 본인② 신청인의 배우자③ 신청인의 1촌 이내 직계혈족(부모, 자녀)으로 한정해 판단합니다.ᴥhttps://1350.moel.go.kr/home/hp/data/faqView.do?faq_idx=1000000722', metadata={'category': '정보제공', 'source': './files/whole', '정책명': '국민취업지원제도'}),
#  Document(page_content='국민취업지원제도ᴥ참여가 어렵습니다.국민취업지원제도는 취업을 지원하는 목적의 사업으로서, 취업을 희망하는 분들 중근로능력과 구직의사가 있는 경우에 참여 가능합니다.ᴥhttps://1350.moel.go.kr/home/hp/data/faqView.do?faq_idx=1000000728', metadata={'category': '정보제공', 'source': './files/whole', '정책명': '국민취업지원제도'}),
#  Document(page_content='국민취업지원제도ᴥⅠ유형으로 1)요건심사형, 2)선발형 청년층, 3)선발형 비경제활동인구 중 하나에 해당되면서, 수급자격이 인정된 이후에는 매월 2회 이상 구직활동 의무를 이행해야 합니다. 구분취업지원서비스 수급요건가구단위 소득요건가구원 재산요건취업경험 요건1) 요건 심사형구직능력 및 의사가 있는 15~69세로 미취업 상태중위소득 60% ↓4억원(15~34세 청년은 5억원) ↓최근 2년 이내100일 또는 800시간 ↑2) 선발형 청년층구직능력 및 의사가 있는 15~34세로 미취업 상태중위소득 120% ↓5억원 ↓3) 선발형 비경활구직능력 및 의사가 있는 15~69세로 미취업 상태중위소득 60% ↓4억원 ↓최근 2년 이내100일 또는 800시간↓ᴥhttps://www.kua.go.kr/uapae010/selectQstn.do?pageIndex=1&pageUnit=10&srchSecd=A&srchTy=&srchKwrd=', metadata={'category': '정보제공', 'source': './files/whole', '정책명': '국민취업지원제도'}),
#  Document(page_content='국민취업지원제도ᴥ국민취업지원제도 정책 소개: 취업을 원하는 사람에게 취업지원서비스를 종합적으로 제공하고 저소득 구직자에게는 생계를 위한 최소화의 소득을 지원하기 위한 제도ᴥ국민취업지원제도 온통 청년 url: https://www.youthcenter.go.kr/youngPlcyUnif/youngPlcyUnifDtl.do?pageIndex=1&frameYn=&bizId=R2024010218403&dtlOpenYn=&plcyTpOpenTy=&plcyCmprInfo=&srchWord=&chargerOrgCdAll=&srchAge=&trgtJynEmp=&trgtJynEmp=&srchSortOrder=1&pageUnit=12', metadata={'category': '정보제공', 'source': './files/whole', '정책명': '국민취업지원제도'})]

# %%
pdf = pd.read_csv('./files/기관_2024-03-04 - 기관_2024-03-04.csv')
print(pdf.columns.to_list())
# Out:
# ['Unnamed: 0', '번호', '정책 ID', '정책 일련번호', '기관 및 지자체 구분', '정책명', '정책 소개', '지원 내용', '지원 규모', '사업 운영 기간', '사업 신청 기간 반복 구분 코드', '사업 신청 기간', '연령', '전공', '취업 상태', '특화 분화', '학력', '거주지 및 소득', '추가 단서 사항', '참여 제한 대상', '신청 절차', '제출 서류', '심사 발표', '신청 사이트 주소', '참고 사이트 주소1', '참고 사이트 주소2', '주관 부처명', '주관 부처 담당자 이름', '주관 부처 담당자 연락처', '운영 기관명', '운영 기관 담당자 이름', '운영 기관 담당자 연락처', '기타 사항', '정책 분야 코드', '정책 분야', '온통 청년 url']

# %%
pdf[['정책명', '정책 소개', '연령', '전공', '취업 상태', '학력', '거주지 및 소득', '추가 단서 사항', '참여 제한 대상']].head()
pdf[(pdf['전공'] != '-') | (pdf['취업 상태'] != '-')][['정책명', '정책 소개', '연령', '전공', '취업 상태', '학력', '거주지 및 소득', '추가 단서 사항', '참여 제한 대상']]

# %%
ddf = pdf[['정책명', '신청 절차', '제출 서류', '심사 발표', '신청 사이트 주소', '참고 사이트 주소1', '참고 사이트 주소2']]

# %%
ddf[(ddf['심사 발표'] != '-') & (ddf['심사 발표'].notna())].head()
ddf[ddf['정책명'] == '청년도약계좌']
# Out:
#         정책명                                              신청 절차 제출 서류  \
# 427  청년도약계좌  [매월]\n가입신청 - 취급은행 앱\n[신청 후 약 2주]\n가입심사 – 서민금융진...   NaN
#
#                                                  심사 발표 신청 사이트 주소  \
# 427  □ 개인 및 가구소득 확인 세부 절차 (약 2주 소요)\n① 나이 및 개인소득 확인...      취급은행
#
#                         참고 사이트 주소1  \
# 427  https://ylaccount.kinfa.or.kr
#
#                                             참고 사이트 주소2
# 427  https://www.kinfa.or.kr/customerService/boardF...

# %% [markdown]
# 더 보면 좋을 것
# - https://github.com/langchain-ai/langchain/blob/master/cookbook/self_query_hotel_search.ipynb
# - raptor : https://github.com/langchain-ai/langchain/blob/master/cookbook/RAPTOR.ipynb

# %% [markdown]
# chromadb 관련
#
# https://python.langchain.com/docs/integrations/vectorstores/chroma
# https://docs.trychroma.com/reference/Client
# https://github.com/chroma-core/chroma
#
# https://gniogolb.tistory.com/18
# https://opentutorials.org/module/6369/32376

# %%
import uuid
import chromadb
from chromadb.config import Settings
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceBgeEmbeddings

client = chromadb.HttpClient(
    host = '175.45.203.113',
    port = "1123",
    settings=Settings(allow_reset=True)
)
client.reset()  # resets the database
collection = client.create_collection("test_collection")

collection.add(
    ids=[str(uuid.uuid1())], metadatas={'testMetadata':'tempt'}, documents='test'
)

embeddings = HuggingFaceEmbeddings(
    model_name="intfloat/multilingual-e5-large",
    model_kwargs={"device": "cuda"},  # streamlit에서는 gpu 없음
    encode_kwargs={"normalize_embeddings": True},
)

# tell LangChain to use our client and collection name
db4 = Chroma(
    client=client,
    collection_name="test_collection",
    embedding_function=embeddings,
)
query = "What did the president say about Ketanji Brown Jackson"
docs = db4.similarity_search(query)
print(docs[0].page_content)
# Out:
# ---------------------------------------------------------------------------
# InvalidDimensionException                 Traceback (most recent call last)
# Cell In[17], line 32
#      26 db4 = Chroma(
#      27     client=client,
#      28     collection_name="test_collection",
#      29     embedding_function=embeddings,
#      30 )
#      31 query = "What did the president say about Ketanji Brown Jackson"
# ---> 32 docs = db4.similarity_search(query)
#      33 print(docs[0].page_content)
#
# File ~/miniforge3/envs/final_env/lib/python3.9/site-packages/langchain_community/vectorstores/chroma.py:348, in Chroma.similarity_search(self, query, k, filter, **kwargs)
#     331 def similarity_search(
#     332     self,
#     333     query: str,
#    (...)
#     336     **kwargs: Any,
#     337 ) -> List[Document]:
#     338     """Run similarity search with Chroma.
#     339
#     340     Args:
#    (...)
#     346         List[Document]: List of documents most similar to the query text.
#     347     """
# --> 348     docs_and_scores = self.similarity_search_with_score(
#     349         query, k, filter=filter, **kwargs
#     350     )
#     351     return [doc for doc, _ in docs_and_scores]
#
# File ~/miniforge3/envs/final_env/lib/python3.9/site-packages/langchain_community/vectorstores/chroma.py:438, in Chroma.similarity_search_with_score(self, query, k, filter, where_document, **kwargs)
#     436 else:
#     437     query_embedding = self._embedding_function.embed_query(query)
# --> 438     results = self.__query_collection(
#     439         query_embeddings=[query_embedding],
#     440         n_results=k,
#     441         where=filter,
#     442         where_document=where_document,
#     443         **kwargs,
#     444     )
#     446 return _results_to_docs_and_scores(results)
#
# File ~/miniforge3/envs/final_env/lib/python3.9/site-packages/langchain_core/utils/utils.py:35, in xor_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      29     invalid_group_names = [", ".join(arg_groups[i]) for i in invalid_groups]
#      30     raise ValueError(
#      31         "Exactly one argument in each of the following"
#      32         " groups must be defined:"
#      33         f" {', '.join(invalid_group_names)}"
#      34     )
# ---> 35 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/final_env/lib/python3.9/site-packages/langchain_community/vectorstores/chroma.py:155, in Chroma.__query_collection(self, query_texts, query_embeddings, n_results, where, where_document, **kwargs)
#     150 except ImportError:
#     151     raise ValueError(
#     152         "Could not import chromadb python package. "
#     153         "Please install it with `pip install chromadb`."
#     154     )
# --> 155 return self._collection.query(
#     156     query_texts=query_texts,
#     157     query_embeddings=query_embeddings,
#     158     n_results=n_results,
#     159     where=where,
#     160     where_document=where_document,
#     161     **kwargs,
#     162 )
#
# File ~/miniforge3/envs/final_env/lib/python3.9/site-packages/chromadb/api/models/Collection.py:345, in Collection.query(self, query_embeddings, query_texts, query_images, query_uris, n_results, where, where_document, include)
#     343 if "data" in include and "uris" not in include:
#     344     valid_include.append("uris")
# --> 345 query_results = self._client._query(
#     346     collection_id=self.id,
#     347     query_embeddings=valid_query_embeddings,
#     348     n_results=valid_n_results,
#     349     where=valid_where,
#     350     where_document=valid_where_document,
#     351     include=include,
#     352 )
#     354 if (
#     355     "data" in include
#     356     and self._data_loader is not None
#     357     and query_results["uris"] is not None
#     358 ):
#     359     query_results["data"] = [
#     360         self._data_loader(uris) for uris in query_results["uris"]
#     361     ]
#
# File ~/miniforge3/envs/final_env/lib/python3.9/site-packages/chromadb/telemetry/opentelemetry/__init__.py:127, in trace_method.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     125 global tracer, granularity
#     126 if trace_granularity < granularity:
# --> 127     return f(*args, **kwargs)
#     128 if not tracer:
#     129     return f(*args, **kwargs)
#
# File ~/miniforge3/envs/final_env/lib/python3.9/site-packages/chromadb/api/fastapi.py:588, in FastAPI._query(self, collection_id, query_embeddings, n_results, where, where_document, include)
#     574 """Gets the nearest neighbors of a single embedding"""
#     575 resp = self._session.post(
#     576     self._api_url + "/collections/" + str(collection_id) + "/query",
#     577     data=json.dumps(
#    (...)
#     585     ),
#     586 )
# --> 588 raise_chroma_error(resp)
#     589 body = json.loads(resp.text)
#     591 return QueryResult(
#     592     ids=body["ids"],
#     593     distances=body.get("distances", None),
#    (...)
#     598     data=None,
#     599 )
#
# File ~/miniforge3/envs/final_env/lib/python3.9/site-packages/chromadb/api/fastapi.py:649, in raise_chroma_error(resp)
#     646     pass
#     648 if chroma_error:
# --> 649     raise chroma_error
#     651 try:
#     652     resp.raise_for_status()
#
# InvalidDimensionException: Embedding dimension 1024 does not match collection dimensionality 384

# %%
result = collection.query(
    query_texts=['test'],
    n_results=1,
)
print(result)
# Out:
# {'ids': [['c0dfa634-e234-11ee-84b0-f220af9362dc']], 'distances': [[0.0]], 'embeddings': None, 'metadatas': [[{'testMetadata': 'tempt'}]], 'documents': [['test']], 'uris': None, 'data': None}
